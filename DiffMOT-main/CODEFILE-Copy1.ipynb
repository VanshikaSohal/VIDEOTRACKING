# %%
import os

# CELL 0 - GPU CHECK
os.system("nvidia-smi")
# !nvidia-smi
# Out:
# Tue Apr  7 17:52:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 573.44                 Driver Version: 573.44         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA T400 4GB              WDDM  |   00000000:01:00.0  On |                  N/A |
# | 38%   31C    P8            N/A  /   31W |     789MiB /   4096MiB |      3%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1908    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A            2968    C+G   ...crosoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A            3216    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A            8724    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10948    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           13844    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A           16908    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           17708    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           20160    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           21680    C+G   ....0.3856.97\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           25556    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           27012    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           28120    C+G   ....0.3856.97\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           28640    C+G   ...y\Comet\Application\comet.exe      N/A      |
# |    0   N/A  N/A           28944    C+G   ...ffice6\promecefpluginhost.exe      N/A      |
# |    0   N/A  N/A           29000    C+G   ...1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A           31164    C+G   ...ole\DellOptimizer.Systray.exe      N/A      |
# |    0   N/A  N/A           31276    C+G   ....0.3856.97\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           32432    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import os
print(os.listdir())
# Out:
# ['.cache', '.conda', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.matplotlib', '.python_history', 'Adity', 'Adityvgg19.ipynb', 'AppData', 'Application Data', 'Assignment_DL.ipynb', 'barplot_script.ipynb', 'Contacts', 'Cookies', 'cswin_test.ipynb', 'data', 'dataframe_test.ipynb', 'deepglobe.zip', 'DG', 'DGCODE.ipynb', 'DiffMOT-main.zip', 'DL_part2.ipynb', 'Documents', 'Downloads', 'dropout_DL.ipynb', 'Favorites', 'Final_dataset_capstone.zip', 'function_test.ipynb', 'H2layer.ipynb', 'h2regularization.ipynb', 'h2_dropout.ipynb', 'h2_earltStopping.ipynb', 'h3fixedearlystop.ipynb', 'h3fixedneurons.ipynb', 'h3fixed_dropouut.ipynb', 'h3L2FixedNeurons.ipynb', 'h3part2.ipynb', 'h3part2_all.ipynb', 'imgtest.ipynb', 'iris.csv', 'iris_bpn.ipynb', 'Links', 'Local Settings', 'malaria_dataset', 'muravgg19.ipynb', 'Mura_VGG19_Classes.ipynb', 'Music', 'My Documents', 'mypercepLR.ipynb', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{96d8f20d-c089-11ef-8ce7-10510739474d}.TxR.0.regtrans-ms', 'NTUSER.DAT{96d8f20d-c089-11ef-8ce7-10510739474d}.TxR.1.regtrans-ms', 'NTUSER.DAT{96d8f20d-c089-11ef-8ce7-10510739474d}.TxR.2.regtrans-ms', 'NTUSER.DAT{96d8f20d-c089-11ef-8ce7-10510739474d}.TxR.blf', 'NTUSER.DAT{96d8f20e-c089-11ef-8ce7-10510739474d}.TM.blf', 'NTUSER.DAT{96d8f20e-c089-11ef-8ce7-10510739474d}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{96d8f20e-c089-11ef-8ce7-10510739474d}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'numpy_opration.ipynb', 'OneDrive', 'PrintHood', 'Rajesh_ML', 'Recent', 'res_dua_unet_no_att_best.h5', 'runs', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'svm_malaria.ipynb', 'svm_pipeline.joblib', 'Templates', 'testvgg19_cifar10.ipynb', 'Untitled.ipynb', 'untitled.py', 'Untitled1.ipynb', 'Untitled10.ipynb', 'Untitled11.ipynb', 'Untitled12.ipynb', 'Untitled13.ipynb', 'Untitled14.ipynb', 'Untitled15.ipynb', 'Untitled16.ipynb', 'Untitled17.ipynb', 'Untitled18.ipynb', 'Untitled19.ipynb', 'Untitled2.ipynb', 'Untitled20.ipynb', 'Untitled21.ipynb', 'Untitled22.ipynb', 'Untitled23.ipynb', 'Untitled24.ipynb', 'Untitled25.ipynb', 'Untitled26.ipynb', 'Untitled27.ipynb', 'Untitled28.ipynb', 'Untitled29.ipynb', 'Untitled3.ipynb', 'Untitled30.ipynb', 'Untitled31.ipynb', 'Untitled32.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Untitled8.ipynb', 'Untitled9.ipynb', 'VANSHIKASOHAL', 'Videos', 'vit_malaria_dataset.ipynb', 'wholedataset.ipynb', 'WPS Cloud Files', 'yolov8s.pt']

# %%
os.chdir("VANSHIKASOHAL")
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'CODEFILE.ipynb', 'DiffMOT-main.zip']

# %%
import zipfile
with zipfile.ZipFile("DiffMOT-main.zip",'r') as zip_ref:
    zip_ref.extractall()
print("extracted")
# Out:
# extracted

# %%
# CELL 1 - CLONE DiffMOT REPO  ← CHANGED (was DiffusionTrack)
#import os
#if not os.path.exists("DiffMot"):
 #  os.system("git clone https://github.com/Kroery/DiffMOT.git")
#os.chdir("DiffMOT")#print("DiffMOT repo cloned!")

# %%
import os

# Install PyTorch (auto compatible)
os.system("pip install torch torchvision torchaudio")

# Main requirements
os.system("pip install -r requirement.txt")

# YOLOX (needed internally)
os.chdir("external/YOLOX")
os.system("pip install -r requirements.txt")
os.system("pip install -e .")

# deep-person-reid
os.chdir("../deep-person-reid")
os.system("pip install -r requirements.txt")
os.system("pip install -e .")

# fast_reid
os.chdir("../fast_reid")
os.system("pip install -r docs/requirements.txt")

# back to main
os.chdir("../../")

# YOLOv8
os.system("pip install ultralytics")

print("ALL INSTALLED")
# Out:
# ALL INSTALLED

# %%
# CELL 3 - TORCH CHECK
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.7.1+cu118
# True

# %%
import os
import zipfile
import shutil
import urllib.request

# STEP 1: Go to DiffMOT folder
#os.chdir("DiffMOT-main")

# STEP 2: Create dataset folders
os.makedirs("datasets/mot/train", exist_ok=True)
os.makedirs("datasets/mot/test", exist_ok=True)

# STEP 3: Download MOT17
print("Downloading MOT17 dataset (~5GB, will take time)...")

url = "https://motchallenge.net/data/MOT17.zip"
zip_path = "datasets/mot/MOT17.zip"

if not os.path.exists(zip_path):
    urllib.request.urlretrieve(url, zip_path)
    print("Download complete!")
else:
    print("Dataset already downloaded.")

# STEP 4: Extract dataset
print("Extracting dataset...")

with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall("datasets/mot/")

# STEP 5: Move files to correct structure
print("Organizing dataset...")

train_src = "datasets/mot/MOT17/train"
test_src  = "datasets/mot/MOT17/test"

train_dst = "datasets/mot/train"
test_dst  = "datasets/mot/test"

for item in os.listdir(train_src):
    src = os.path.join(train_src, item)
    dst = os.path.join(train_dst, item)
    if not os.path.exists(dst):
        shutil.move(src, dst)

for item in os.listdir(test_src):
    src = os.path.join(test_src, item)
    dst = os.path.join(test_dst, item)
    if not os.path.exists(dst):
        shutil.move(src, dst)

# STEP 6: Cleanup
shutil.rmtree("datasets/mot/MOT17")
os.remove(zip_path)

print(" MOT17 dataset ready!")

# STEP 7: Verify
print("\nTrain sequences:")
print(os.listdir("datasets/mot/train"))
# Out:
# Downloading MOT17 dataset (~5GB, will take time)...
# Download complete!
# Extracting dataset...
# Organizing dataset...
#  MOT17 dataset ready!
#
# Train sequences:
# ['MOT17-02-DPM', 'MOT17-02-FRCNN', 'MOT17-02-SDP', 'MOT17-04-DPM', 'MOT17-04-FRCNN', 'MOT17-04-SDP', 'MOT17-05-DPM', 'MOT17-05-FRCNN', 'MOT17-05-SDP', 'MOT17-09-DPM', 'MOT17-09-FRCNN', 'MOT17-09-SDP', 'MOT17-10-DPM', 'MOT17-10-FRCNN', 'MOT17-10-SDP', 'MOT17-11-DPM', 'MOT17-11-FRCNN', 'MOT17-11-SDP', 'MOT17-13-DPM', 'MOT17-13-FRCNN', 'MOT17-13-SDP']

# %%
import os
print(os.path.exists("datasets/mot/train"))
import os
print(os.listdir("datasets/mot/train"))
# Out:
# True
# ['MOT17-02-DPM', 'MOT17-02-FRCNN', 'MOT17-02-SDP', 'MOT17-04-DPM', 'MOT17-04-FRCNN', 'MOT17-04-SDP', 'MOT17-05-DPM', 'MOT17-05-FRCNN', 'MOT17-05-SDP', 'MOT17-09-DPM', 'MOT17-09-FRCNN', 'MOT17-09-SDP', 'MOT17-10-DPM', 'MOT17-10-FRCNN', 'MOT17-10-SDP', 'MOT17-11-DPM', 'MOT17-11-FRCNN', 'MOT17-11-SDP', 'MOT17-13-DPM', 'MOT17-13-FRCNN', 'MOT17-13-SDP']

# %%
import os
#os.chdir("DiffMOT-main")
ret = os.system("python mot_data_process.py")
if ret != 0:
    print("WARNING: mot_data_process.py had errors - possibly missing MOT20, may be okay if MOT17 processed fine")
    # Manually verify
    import os
    print(os.listdir("datasets/mot/train"))
print("Data preprocessing done!")
# Out:
# WARNING: mot_data_process.py had errors - possibly missing MOT20, may be okay if MOT17 processed fine
# ['MOT17-02-DPM', 'MOT17-02-FRCNN', 'MOT17-02-SDP', 'MOT17-04-DPM', 'MOT17-04-FRCNN', 'MOT17-04-SDP', 'MOT17-05-DPM', 'MOT17-05-FRCNN', 'MOT17-05-SDP', 'MOT17-09-DPM', 'MOT17-09-FRCNN', 'MOT17-09-SDP', 'MOT17-10-DPM', 'MOT17-10-FRCNN', 'MOT17-10-SDP', 'MOT17-11-DPM', 'MOT17-11-FRCNN', 'MOT17-11-SDP', 'MOT17-13-DPM', 'MOT17-13-FRCNN', 'MOT17-13-SDP']
# Data preprocessing done!

# %%
import os
import urllib.request

# go inside project (if not already)
#os.chdir("DiffMOT-main")

# create folder
os.makedirs("pretrained/motion", exist_ok=True)

# download file
url = "https://github.com/Kroery/DiffMOT/releases/download/v1.0/MOT_epoch800.pt"
output_path = "pretrained/motion/MOT_epoch800.pt"

if not os.path.exists(output_path):
    print("Downloading motion model...")
    urllib.request.urlretrieve(url, output_path)
    print("Download complete!")
else:
    print("Model already exists.")

# check file size
size_mb = os.path.getsize(output_path) / (1024 * 1024)
print(f"File size: {size_mb:.2f} MB")

print("Motion model ready!")
# Out:
# Downloading motion model...
# Download complete!
# File size: 168.32 MB
# Motion model ready!

# %%
import os
import urllib.request

# go inside project (if not already)
#os.chdir("DiffMOT-main")

# create folder
os.makedirs("pretrained/reid", exist_ok=True)

# download file
url = "https://github.com/Kroery/DiffMOT/releases/download/v1.0/mot17_sbs_S50.pth"
output_path = "pretrained/reid/mot17_sbs_S50.pth"

if not os.path.exists(output_path):
    print("Downloading ReID model...")
    urllib.request.urlretrieve(url, output_path)
    print("Download complete!")
else:
    print("Model already exists.")

# check file size
size_mb = os.path.getsize(output_path) / (1024 * 1024)
print(f"File size: {size_mb:.2f} MB")

print("ReID model ready!")
# Out:
# Downloading ReID model...
# Download complete!
# File size: 302.89 MB
# ReID model ready!

# %%
import os
import numpy as np
import torch
from ultralytics import YOLO

# go to project folder
#os.chdir("DiffMOT-main")

# CONFIG
MODEL_WEIGHTS = "yolov8n.pt"#check
CONF_THRESH   = 0.3
IOU_THRESH    = 0.45
IMG_SIZE      = 1280
PERSON_CLASS  = 0

# device selection
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

model = YOLO(MODEL_WEIGHTS)
model.to(device)

# MOT17 sequences
seqs = ['MOT17-02-FRCNN','MOT17-04-FRCNN','MOT17-05-FRCNN','MOT17-09-FRCNN','MOT17-10-FRCNN','MOT17-11-FRCNN','MOT17-13-FRCNN']

for seq in seqs:
    img_dir  = f"datasets/mot/train/{seq}/img1"
    det_dir  = f"datasets/mot/train/{seq}/det"
    det_path = f"{det_dir}/det.txt"

    if not os.path.exists(img_dir):
        print(f"Skipping {seq}, folder not found")
        continue

    os.makedirs(det_dir, exist_ok=True)

    frames = sorted(os.listdir(img_dir))
    print(f"\n[{seq}] Running YOLOv8 on {len(frames)} frames...")

    lines = []

    for frame_file in frames:
        frame_id = int(os.path.splitext(frame_file)[0])
        img_path = os.path.join(img_dir, frame_file)

        results = model.predict(
            source  = img_path,
            conf    = CONF_THRESH,
            iou     = IOU_THRESH,
            imgsz   = IMG_SIZE,
            classes = [PERSON_CLASS],
            verbose = False,
            device  = device
        )

        boxes = results[0].boxes

        if boxes is not None and len(boxes) > 0:
            xyxy  = boxes.xyxy.cpu().numpy()
            confs = boxes.conf.cpu().numpy()

            for (x1, y1, x2, y2), conf in zip(xyxy, confs):
                w = x2 - x1
                h = y2 - y1
                lines.append(f"{frame_id},-1,{x1:.2f},{y1:.2f},{w:.2f},{h:.2f},{conf:.4f},-1,-1,-1")

    with open(det_path, "w") as f:
        f.write("\n".join(lines))

    print(f"Saved {len(lines)} detections to {det_path}")

print("YOLOv8 detections complete")
# Out:
# Using device: cuda
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 11.3MB/s 0.6s.5s<0.0s
#
# [MOT17-02-FRCNN] Running YOLOv8 on 600 frames...
# Saved 7643 detections to datasets/mot/train/MOT17-02-FRCNN/det/det.txt
#
# [MOT17-04-FRCNN] Running YOLOv8 on 1050 frames...
# Saved 29088 detections to datasets/mot/train/MOT17-04-FRCNN/det/det.txt
#
# [MOT17-05-FRCNN] Running YOLOv8 on 837 frames...
# Saved 5316 detections to datasets/mot/train/MOT17-05-FRCNN/det/det.txt
#
# [MOT17-09-FRCNN] Running YOLOv8 on 525 frames...
# Saved 5153 detections to datasets/mot/train/MOT17-09-FRCNN/det/det.txt
#
# [MOT17-10-FRCNN] Running YOLOv8 on 654 frames...
# Saved 9006 detections to datasets/mot/train/MOT17-10-FRCNN/det/det.txt
#
# [MOT17-11-FRCNN] Running YOLOv8 on 900 frames...
# Saved 7977 detections to datasets/mot/train/MOT17-11-FRCNN/det/det.txt
#
# [MOT17-13-FRCNN] Running YOLOv8 on 750 frames...
# Saved 5887 detections to datasets/mot/train/MOT17-13-FRCNN/det/det.txt
# YOLOv8 detections complete

# %%
import os
for seq in seqs:
    path=f"datasets/mot/train/{seq}/det/det.txt"
    print(seq,"->",os.path.exists(path))
# Out:
# MOT17-02-FRCNN -> True
# MOT17-04-FRCNN -> True
# MOT17-05-FRCNN -> True
# MOT17-09-FRCNN -> True
# MOT17-10-FRCNN -> True
# MOT17-11-FRCNN -> True
# MOT17-13-FRCNN -> True

# %%
import os

#os.chdir("DiffMOT-main")

seqs = ['MOT17-02-FRCNN','MOT17-04-FRCNN','MOT17-05-FRCNN','MOT17-09-FRCNN','MOT17-10-FRCNN','MOT17-11-FRCNN','MOT17-13-FRCNN']

print("Detection file check:")

for seq in seqs:
    det_path = f"datasets/mot/train/{seq}/det/det.txt"

    if os.path.exists(det_path):
        lines = open(det_path).readlines()
        print(f"{seq}: {len(lines)} detections")

        if len(lines) > 0:
            print("Sample:", lines[0].strip())
        else:
            print("EMPTY FILE")

    else:
        print(f"{seq}: det.txt NOT FOUND")
# Out:
# Detection file check:
# MOT17-02-FRCNN: 7643 detections
# Sample: 1,-1,1338.96,416.53,167.61,374.16,0.8653,-1,-1,-1
# MOT17-04-FRCNN: 29088 detections
# Sample: 1,-1,103.05,548.87,76.52,246.55,0.8761,-1,-1,-1
# MOT17-05-FRCNN: 5316 detections
# Sample: 1,-1,17.99,148.51,73.29,190.32,0.8976,-1,-1,-1
# MOT17-09-FRCNN: 5153 detections
# Sample: 1,-1,1288.37,460.81,71.61,198.44,0.8149,-1,-1,-1
# MOT17-10-FRCNN: 9006 detections
# Sample: 1,-1,1475.04,419.19,75.20,169.65,0.8781,-1,-1,-1
# MOT17-11-FRCNN: 7977 detections
# Sample: 1,-1,0.00,26.08,347.06,989.28,0.8907,-1,-1,-1
# MOT17-13-FRCNN: 5887 detections
# Sample: 1,-1,0.08,661.50,49.74,222.84,0.8220,-1,-1,-1

# %%
import yaml
import os

#os.chdir("DiffMOT-main")

config_path = "configs/mot17_test.yaml"

with open(config_path, "r") as f:
    config = yaml.safe_load(f)

print("Original config:")
print(yaml.dump(config))


# FIXED PATHS (LOCAL)

config["det_dir"]    = "datasets/mot/train"
config["reid_dir"]   = "pretrained/reid"
config["model_path"] = "pretrained/motion/MOT_epoch800.pt"
config["info_dir"]   = "datasets/mot/train"
config["save_dir"]   = "outputs/mot17"

config["device"]="cuda"
config["gpus"]=[0]
# thresholds (keep same)
config["high_thres"]  = 0.6
config["low_thres"]   = 0.1
config["w_assoc_emb"] = 2.2
config["aw_param"]    = 1.7
config["batch_size"]=512

# save config
with open(config_path, "w") as f:
    yaml.dump(config, f)

print("Updated config saved\n")

with open(config_path) as f:
    print(f.read())
# Out:
# Original config:
# augment: true
# aw_param: 1.7
# batch_size: 2048
# data_dir: /mnt/8T/home/estar/data/DanceTrack/trackers_gt_GSI
# det_dir: datasets/mot/train
# device: cuda
# diffnet: HMINet
# encoder_dim: 256
# epochs: 800
# eps: 0.001
# eval_at: 800
# eval_device: None
# eval_every: 20
# eval_expname: mot_ddm_1000_deeper
# eval_mode: true
# gpus:
# - 0
# high_thres: 0.6
# info_dir: datasets/mot/train
# interval: 5
# low_thres: 0.1
# lr: 0.0001
# model_path: pretrained/motion/MOT_epoch800.pt
# preprocess_workers: 16
# reid_dir: pretrained/reid
# save_dir: outputs/mot17
# seed: 123
# tf_layer: 3
# w_assoc_emb: 2.2
#
# Updated config saved
#
# augment: true
# aw_param: 1.7
# batch_size: 512
# data_dir: /mnt/8T/home/estar/data/DanceTrack/trackers_gt_GSI
# det_dir: datasets/mot/train
# device: cuda
# diffnet: HMINet
# encoder_dim: 256
# epochs: 800
# eps: 0.001
# eval_at: 800
# eval_device: None
# eval_every: 20
# eval_expname: mot_ddm_1000_deeper
# eval_mode: true
# gpus:
# - 0
# high_thres: 0.6
# info_dir: datasets/mot/train
# interval: 5
# low_thres: 0.1
# lr: 0.0001
# model_path: pretrained/motion/MOT_epoch800.pt
# preprocess_workers: 16
# reid_dir: pretrained/reid
# save_dir: outputs/mot17
# seed: 123
# tf_layer: 3
# w_assoc_emb: 2.2

# %%
import os
print(os.listdir("datasets/mot/train"))
# Out:
# ['MOT17-02-DPM', 'MOT17-02-FRCNN', 'MOT17-02-SDP', 'MOT17-04-DPM', 'MOT17-04-FRCNN', 'MOT17-04-SDP', 'MOT17-05-DPM', 'MOT17-05-FRCNN', 'MOT17-05-SDP', 'MOT17-09-DPM', 'MOT17-09-FRCNN', 'MOT17-09-SDP', 'MOT17-10-DPM', 'MOT17-10-FRCNN', 'MOT17-10-SDP', 'MOT17-11-DPM', 'MOT17-11-FRCNN', 'MOT17-11-SDP', 'MOT17-13-DPM', 'MOT17-13-FRCNN', 'MOT17-13-SDP']

# %%
print(open("configs/mot17_test.yaml").read())
# Out:
# augment: true
# aw_param: 1.7
# batch_size: 512
# data_dir: /mnt/8T/home/estar/data/DanceTrack/trackers_gt_GSI
# det_dir: datasets/mot/train
# device: cuda
# diffnet: HMINet
# encoder_dim: 256
# epochs: 800
# eps: 0.001
# eval_at: 800
# eval_device: None
# eval_every: 20
# eval_expname: mot_ddm_1000_deeper
# eval_mode: true
# gpus:
# - 0
# high_thres: 0.6
# info_dir: datasets/mot/train
# interval: 5
# low_thres: 0.1
# lr: 0.0001
# model_path: pretrained/motion/MOT_epoch800.pt
# preprocess_workers: 16
# reid_dir: pretrained/reid
# save_dir: outputs/mot17
# seed: 123
# tf_layer: 3
# w_assoc_emb: 2.2

# %%
import torch
print("CUDA AVAILABLE",torch.cuda.is_available())
print("GPU COUNT:",torch.cuda.device_count())
print("GPU NAME:",torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NO GPU")
# Out:
# CUDA AVAILABLE True
# GPU COUNT: 1
# GPU NAME: NVIDIA T400 4GB

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Using cached tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from tensorboardX) (24.2)
# Requirement already satisfied: protobuf>=3.20 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from tensorboardX) (6.33.0)
# Using cached tensorboardx-2.6.5-py3-none-any.whl (87 kB)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.5
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install lap cython bbox motmetrics scipy opencv-python tqdm matplotlib scikit-learn filterpy
# Out:
# Requirement already satisfied: lap in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (0.5.13)
# Requirement already satisfied: cython in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (3.2.4)
# Collecting bbox
#   Using cached bbox-0.9.4-py3-none-any.whl.metadata (576 bytes)
# Collecting motmetrics
#   Downloading motmetrics-1.4.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (1.15.1)
# Requirement already satisfied: opencv-python in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (4.11.0.86)
# Requirement already satisfied: tqdm in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (4.67.1)
# Requirement already satisfied: matplotlib in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (3.10.0)
# Requirement already satisfied: scikit-learn in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (1.6.1)
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.21.6 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from lap) (1.26.4)
# Collecting pyquaternion<0.10.0,>=0.9.5 (from bbox)
#   Downloading pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pandas>=0.23.1 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from motmetrics) (2.2.3)
# Collecting xmltodict>=0.12.0 (from motmetrics)
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: colorama in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.23.1->motmetrics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.23.1->motmetrics) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\rajes\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading bbox-0.9.4-py3-none-any.whl (14 kB)
# Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Downloading motmetrics-1.4.0-py3-none-any.whl (161 kB)
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (pyproject.toml): started
#   Building wheel for filterpy (pyproject.toml): finished with status 'done'
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110631 sha256=5c33bd7b6a70c431b60d561d3712c4dfe2a9f75cf2430bd753896e35e79622c0
#   Stored in directory: c:\users\rajes\appdata\local\pip\cache\wheels\12\dc\3c\e12983eac132d00f82a20c6cbe7b42ce6e96190ef8fa2d15e1
# Successfully built filterpy
# Installing collected packages: xmltodict, pyquaternion, bbox, motmetrics, filterpy
#
#    ------------------------ --------------- 3/5 [motmetrics]
#    -------------------------------- ------- 4/5 [filterpy]
#    -------------------------------- ------- 4/5 [filterpy]
#    ---------------------------------------- 5/5 [filterpy]
#
# Successfully installed bbox-0.9.4 filterpy-1.4.5 motmetrics-1.4.0 pyquaternion-0.9.9 xmltodict-1.0.4
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install cython_bbox==0.1.3
# Out:
# Collecting cython_bbox==0.1.3
#   Downloading cython_bbox-0.1.3.tar.gz (41 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#     File "C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#       return hook(config_settings)
#              ^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\rajes\AppData\Local\Temp\pip-build-env-m3s_gmbv\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\rajes\AppData\Local\Temp\pip-build-env-m3s_gmbv\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#       self.run_setup()
#     File "C:\Users\rajes\AppData\Local\Temp\pip-build-env-m3s_gmbv\overlay\Lib\site-packages\setuptools\build_meta.py", line 520, in run_setup
#       super().run_setup(setup_script=setup_script)
#     File "C:\Users\rajes\AppData\Local\Temp\pip-build-env-m3s_gmbv\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#       exec(code, locals())
#     File "<string>", line 10, in <module>
#   ModuleNotFoundError: No module named 'Cython'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Failed to build 'cython_bbox' when getting requirements to build wheel

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\vansh\VANSHIKASOHAL
# ['.ipynb_checkpoints', 'CODEFILE.ipynb', 'DiffMOT-main', 'Untitled11.ipynb']

# %%
import os

for root, dirs, files in os.walk("."):
    print("\n📁", root)
    for d in dirs:
        print("  📂", d)
    for f in files:
        print("  📄", f)
# Out:
# 📁 .
#   📂 .ipynb_checkpoints
#   📂 DiffMOT-main
#   📄 CODEFILE.ipynb
#   📄 Untitled11.ipynb
#
# 📁 .\.ipynb_checkpoints
#   📄 CODEFILE-checkpoint.ipynb
#   📄 Untitled11-checkpoint.ipynb
#
# 📁 .\DiffMOT-main
#   📂 .idea
#   📂 .ipynb_checkpoints
#   📂 assets
#   📂 configs
#   📂 dataset
#   📂 external
#   📂 models
#   📂 tracker
#   📂 tracking_utils
#   📂 __pycache__
#   📄 dancetrack_data_process.py
#   📄 diffmot.py
#   📄 LICENSE
#   📄 main.py
#   📄 mot_data_process.py
#   📄 README.md
#   📄 requirement.txt
#   📄 sports_data_process.py
#
# 📁 .\DiffMOT-main\.idea
#   📂 inspectionProfiles
#   📄 .gitignore
#   📄 .name
#   📄 deployment.xml
#   📄 DiffMOT_git.iml
#   📄 misc.xml
#   📄 modules.xml
#   📄 vcs.xml
#
# 📁 .\DiffMOT-main\.idea\inspectionProfiles
#   📄 profiles_settings.xml
#
# 📁 .\DiffMOT-main\.ipynb_checkpoints
#
# 📁 .\DiffMOT-main\assets
#   📄 ddmp_git.png
#   📄 DiffMOT_DanceTrack.gif
#   📄 diffmot_git.png
#   📄 DiffMOT_SportsMOT.gif
#   📄 teaser_git.png
#
# 📁 .\DiffMOT-main\configs
#   📄 .DS_Store
#   📄 dancetrack.yaml
#   📄 dancetrack_test.yaml
#   📄 mot.yaml
#   📄 mot17_test.yaml
#   📄 mot20_test.yaml
#   📄 sportsmot.yaml
#   📄 sportsmot_test.yaml
#
# 📁 .\DiffMOT-main\dataset
#   📂 .ipynb_checkpoints
#   📂 __pycache__
#   📄 dataset.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\dataset\.ipynb_checkpoints
#   📄 dataset-checkpoint.py
#   📄 __init__-checkpoint.py
#
# 📁 .\DiffMOT-main\dataset\__pycache__
#   📄 dataset.cpython-37.pyc
#   📄 __init__.cpython-37.pyc
#
# 📁 .\DiffMOT-main\external
#   📂 adaptors
#   📂 deep-person-reid
#   📂 fast_reid
#   📂 TrackEval
#   📂 YOLOX
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\adaptors
#   📄 detector.py
#   📄 fastreid_adaptor.py
#   📄 yolox_adaptor.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid
#   📂 configs
#   📂 docs
#   📂 projects
#   📂 scripts
#   📂 tools
#   📂 torchreid
#   📄 .flake8
#   📄 .isort.cfg
#   📄 .style.yapf
#   📄 LICENSE
#   📄 linter.sh
#   📄 README.rst
#   📄 requirements.txt
#   📄 setup.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\configs
#   📄 im_osnet_ain_x1_0_softmax_256x128_amsgrad_cosine.yaml
#   📄 im_osnet_ibn_x1_0_softmax_256x128_amsgrad.yaml
#   📄 im_osnet_x0_25_softmax_256x128_amsgrad.yaml
#   📄 im_osnet_x0_5_softmax_256x128_amsgrad.yaml
#   📄 im_osnet_x0_75_softmax_256x128_amsgrad.yaml
#   📄 im_osnet_x1_0_softmax_256x128_amsgrad.yaml
#   📄 im_osnet_x1_0_softmax_256x128_amsgrad_cosine.yaml
#   📄 im_r50fc512_softmax_256x128_amsgrad.yaml
#   📄 im_r50_softmax_256x128_amsgrad.yaml
#
# 📁 .\DiffMOT-main\external\deep-person-reid\docs
#   📂 figures
#   📂 pkg
#   📄 AWESOME_REID.md
#   📄 conf.py
#   📄 datasets.rst
#   📄 evaluation.rst
#   📄 index.rst
#   📄 Makefile
#   📄 MODEL_ZOO.md
#   📄 requirements.txt
#   📄 user_guide.rst
#
# 📁 .\DiffMOT-main\external\deep-person-reid\docs\figures
#   📄 actmap.jpg
#   📄 ranking_results.jpg
#
# 📁 .\DiffMOT-main\external\deep-person-reid\docs\pkg
#   📄 data.rst
#   📄 engine.rst
#   📄 losses.rst
#   📄 metrics.rst
#   📄 models.rst
#   📄 optim.rst
#   📄 utils.rst
#
# 📁 .\DiffMOT-main\external\deep-person-reid\projects
#   📂 attribute_recognition
#   📂 DML
#   📂 OSNet_AIN
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\deep-person-reid\projects\attribute_recognition
#   📂 datasets
#   📂 models
#   📄 default_parser.py
#   📄 main.py
#   📄 README.md
#   📄 train.sh
#
# 📁 .\DiffMOT-main\external\deep-person-reid\projects\attribute_recognition\datasets
#   📄 dataset.py
#   📄 pa100k.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\projects\attribute_recognition\models
#   📄 osnet.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\projects\DML
#   📄 default_config.py
#   📄 dml.py
#   📄 im_osnet_x1_0_dml_256x128_amsgrad_cosine.yaml
#   📄 main.py
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\deep-person-reid\projects\OSNet_AIN
#   📄 default_config.py
#   📄 main.py
#   📄 nas.yaml
#   📄 osnet_child.py
#   📄 osnet_search.py
#   📄 README.md
#   📄 softmax_nas.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\scripts
#   📄 default_config.py
#   📄 main.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\tools
#   📄 compute_mean_std.py
#   📄 export.py
#   📄 parse_test_res.py
#   📄 visualize_actmap.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid
#   📂 data
#   📂 engine
#   📂 losses
#   📂 metrics
#   📂 models
#   📂 optim
#   📂 utils
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\data
#   📂 datasets
#   📄 datamanager.py
#   📄 sampler.py
#   📄 transforms.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\data\datasets
#   📂 image
#   📂 video
#   📄 dataset.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\data\datasets\image
#   📄 cuhk01.py
#   📄 cuhk02.py
#   📄 cuhk03.py
#   📄 cuhksysu.py
#   📄 dukemtmcreid.py
#   📄 grid.py
#   📄 ilids.py
#   📄 market1501.py
#   📄 msmt17.py
#   📄 prid.py
#   📄 sensereid.py
#   📄 university1652.py
#   📄 viper.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\data\datasets\video
#   📄 dukemtmcvidreid.py
#   📄 ilidsvid.py
#   📄 mars.py
#   📄 prid2011.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\engine
#   📂 image
#   📂 video
#   📄 engine.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\engine\image
#   📄 softmax.py
#   📄 triplet.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\engine\video
#   📄 softmax.py
#   📄 triplet.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\losses
#   📄 cross_entropy_loss.py
#   📄 hard_mine_triplet_loss.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\metrics
#   📂 rank_cylib
#   📄 accuracy.py
#   📄 distance.py
#   📄 rank.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\metrics\rank_cylib
#   📄 Makefile
#   📄 rank_cy.pyx
#   📄 setup.py
#   📄 test_cython.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\models
#   📄 densenet.py
#   📄 hacnn.py
#   📄 inceptionresnetv2.py
#   📄 inceptionv4.py
#   📄 mlfn.py
#   📄 mobilenetv2.py
#   📄 mudeep.py
#   📄 nasnet.py
#   📄 osnet.py
#   📄 osnet_ain.py
#   📄 pcb.py
#   📄 resnet.py
#   📄 resnetmid.py
#   📄 resnet_ibn_a.py
#   📄 resnet_ibn_b.py
#   📄 senet.py
#   📄 shufflenet.py
#   📄 shufflenetv2.py
#   📄 squeezenet.py
#   📄 xception.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\optim
#   📄 lr_scheduler.py
#   📄 optimizer.py
#   📄 radam.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\utils
#   📂 GPU-Re-Ranking
#   📄 avgmeter.py
#   📄 feature_extractor.py
#   📄 loggers.py
#   📄 model_complexity.py
#   📄 reidtools.py
#   📄 rerank.py
#   📄 tools.py
#   📄 torchtools.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\utils\GPU-Re-Ranking
#   📂 extension
#   📄 gnn_reranking.py
#   📄 main.py
#   📄 README.md
#   📄 utils.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\utils\GPU-Re-Ranking\extension
#   📂 adjacency_matrix
#   📂 propagation
#   📄 make.sh
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\utils\GPU-Re-Ranking\extension\adjacency_matrix
#   📄 build_adjacency_matrix.cpp
#   📄 build_adjacency_matrix_kernel.cu
#   📄 setup.py
#
# 📁 .\DiffMOT-main\external\deep-person-reid\torchreid\utils\GPU-Re-Ranking\extension\propagation
#   📄 gnn_propagate.cpp
#   📄 gnn_propagate_kernel.cu
#   📄 setup.py
#
# 📁 .\DiffMOT-main\external\fast_reid
#   📂 .github
#   📂 configs
#   📂 datasets
#   📂 demo
#   📂 docker
#   📂 docs
#   📂 fastreid
#   📂 projects
#   📂 tests
#   📂 tools
#   📄 CHANGELOG.md
#   📄 fast_reid_interfece.py
#   📄 GETTING_STARTED.md
#   📄 INSTALL.md
#   📄 LICENSE
#   📄 MODEL_ZOO.md
#   📄 README.md
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\.github
#   📂 ISSUE_TEMPLATE
#   📂 workflows
#   📄 FastReID-Logo.png
#   📄 wechat_group.png
#
# 📁 .\DiffMOT-main\external\fast_reid\.github\ISSUE_TEMPLATE
#   📄 bugs.md
#   📄 config.yml
#   📄 questions-help-support.md
#   📄 unexpected-problems-bugs.md
#
# 📁 .\DiffMOT-main\external\fast_reid\.github\workflows
#   📄 issue_auto_close.yml
#   📄 lint_python.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs
#   📂 dancetrack
#   📂 DukeMTMC
#   📂 Market1501
#   📂 MOT17
#   📂 MOT20
#   📂 MSMT17
#   📂 VehicleID
#   📂 VeRi
#   📂 VERIWild
#   📄 Base-AGW.yml
#   📄 Base-bagtricks.yml
#   📄 Base-MGN.yml
#   📄 Base-SBS.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\dancetrack
#   📄 sbs_S50.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\DukeMTMC
#   📄 AGW_R101-ibn.yml
#   📄 AGW_R50-ibn.yml
#   📄 AGW_R50.yml
#   📄 AGW_S50.yml
#   📄 bagtricks_R101-ibn.yml
#   📄 bagtricks_R50-ibn.yml
#   📄 bagtricks_R50.yml
#   📄 bagtricks_S50.yml
#   📄 mgn_R50-ibn.yml
#   📄 sbs_R101-ibn.yml
#   📄 sbs_R50-ibn.yml
#   📄 sbs_R50.yml
#   📄 sbs_S50.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\Market1501
#   📄 AGW_R101-ibn.yml
#   📄 AGW_R50-ibn.yml
#   📄 AGW_R50.yml
#   📄 AGW_S50.yml
#   📄 bagtricks_R101-ibn.yml
#   📄 bagtricks_R50-ibn.yml
#   📄 bagtricks_R50.yml
#   📄 bagtricks_S50.yml
#   📄 bagtricks_vit.yml
#   📄 mgn_R50-ibn.yml
#   📄 sbs_R101-ibn.yml
#   📄 sbs_R50-ibn.yml
#   📄 sbs_R50.yml
#   📄 sbs_S50.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\MOT17
#   📄 AGW_R101-ibn.yml
#   📄 AGW_R50-ibn.yml
#   📄 AGW_R50.yml
#   📄 AGW_S50.yml
#   📄 bagtricks_R101-ibn.yml
#   📄 bagtricks_R50-ibn.yml
#   📄 bagtricks_R50.yml
#   📄 bagtricks_S50.yml
#   📄 mgn_R50-ibn.yml
#   📄 sbs_R101-ibn.yml
#   📄 sbs_R50-ibn.yml
#   📄 sbs_R50.yml
#   📄 sbs_S50.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\MOT20
#   📄 AGW_R101-ibn.yml
#   📄 AGW_R50-ibn.yml
#   📄 AGW_R50.yml
#   📄 AGW_S50.yml
#   📄 bagtricks_R101-ibn.yml
#   📄 bagtricks_R50-ibn.yml
#   📄 bagtricks_R50.yml
#   📄 bagtricks_S50.yml
#   📄 mgn_R50-ibn.yml
#   📄 sbs_R101-ibn.yml
#   📄 sbs_R50-ibn.yml
#   📄 sbs_R50.yml
#   📄 sbs_S50.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\MSMT17
#   📄 AGW_R101-ibn.yml
#   📄 AGW_R50-ibn.yml
#   📄 AGW_R50.yml
#   📄 AGW_S50.yml
#   📄 bagtricks_R101-ibn.yml
#   📄 bagtricks_R50-ibn.yml
#   📄 bagtricks_R50.yml
#   📄 bagtricks_S50.yml
#   📄 mgn_R50-ibn.yml
#   📄 sbs_R101-ibn.yml
#   📄 sbs_R50-ibn.yml
#   📄 sbs_R50.yml
#   📄 sbs_S50.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\VehicleID
#   📄 bagtricks_R50-ibn.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\VeRi
#   📄 sbs_R50-ibn.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\configs\VERIWild
#   📄 bagtricks_R50-ibn.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\datasets
#   📄 generate_mot_patches.py
#
# 📁 .\DiffMOT-main\external\fast_reid\demo
#   📄 demo.py
#   📄 plot_roc_with_pickle.py
#   📄 predictor.py
#   📄 README.md
#   📄 visualize_result.py
#
# 📁 .\DiffMOT-main\external\fast_reid\docker
#   📄 Dockerfile
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\fast_reid\docs
#   📂 modules
#   📂 _static
#   📄 conf.py
#   📄 index.rst
#   📄 Makefile
#   📄 README.md
#   📄 requirements.txt
#
# 📁 .\DiffMOT-main\external\fast_reid\docs\modules
#   📄 checkpoint.rst
#   📄 config.rst
#   📄 data.rst
#   📄 data_transforms.rst
#   📄 engine.rst
#   📄 evaluation.rst
#   📄 index.rst
#   📄 layers.rst
#   📄 modeling.rst
#   📄 solver.rst
#   📄 utils.rst
#
# 📁 .\DiffMOT-main\external\fast_reid\docs\_static
#   📂 css
#
# 📁 .\DiffMOT-main\external\fast_reid\docs\_static\css
#   📄 custom.css
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid
#   📂 config
#   📂 data
#   📂 engine
#   📂 evaluation
#   📂 layers
#   📂 modeling
#   📂 solver
#   📂 utils
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\config
#   📄 config.py
#   📄 defaults.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\data
#   📂 datasets
#   📂 samplers
#   📂 transforms
#   📄 build.py
#   📄 common.py
#   📄 data_utils.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\data\datasets
#   📄 AirportALERT.py
#   📄 bases.py
#   📄 caviara.py
#   📄 cuhk03.py
#   📄 cuhk_sysu.py
#   📄 dancetrack.py
#   📄 dukemtmcreid.py
#   📄 grid.py
#   📄 iLIDS.py
#   📄 lpw.py
#   📄 market1501.py
#   📄 mot17.py
#   📄 mot20.py
#   📄 mot20_.py
#   📄 msmt17.py
#   📄 pes3d.py
#   📄 pku.py
#   📄 prai.py
#   📄 prid.py
#   📄 saivt.py
#   📄 sensereid.py
#   📄 shinpuhkan.py
#   📄 sysu_mm.py
#   📄 thermalworld.py
#   📄 vehicleid.py
#   📄 veri.py
#   📄 veriwild.py
#   📄 viper.py
#   📄 wildtracker.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\data\samplers
#   📄 data_sampler.py
#   📄 imbalance_sampler.py
#   📄 triplet_sampler.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\data\transforms
#   📄 autoaugment.py
#   📄 build.py
#   📄 functional.py
#   📄 transforms.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\engine
#   📄 defaults.py
#   📄 hooks.py
#   📄 launch.py
#   📄 train_loop.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\evaluation
#   📂 rank_cylib
#   📄 clas_evaluator.py
#   📄 evaluator.py
#   📄 query_expansion.py
#   📄 rank.py
#   📄 reid_evaluation.py
#   📄 rerank.py
#   📄 roc.py
#   📄 testing.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\evaluation\rank_cylib
#   📄 Makefile
#   📄 rank_cy.c
#   📄 rank_cy.pyx
#   📄 roc_cy.c
#   📄 roc_cy.pyx
#   📄 setup.py
#   📄 test_cython.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\layers
#   📄 activation.py
#   📄 any_softmax.py
#   📄 batch_norm.py
#   📄 context_block.py
#   📄 drop.py
#   📄 frn.py
#   📄 gather_layer.py
#   📄 helpers.py
#   📄 non_local.py
#   📄 pooling.py
#   📄 se_layer.py
#   📄 splat.py
#   📄 weight_init.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling
#   📂 backbones
#   📂 heads
#   📂 losses
#   📂 meta_arch
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling\backbones
#   📂 regnet
#   📄 build.py
#   📄 mobilenet.py
#   📄 mobilenetv3.py
#   📄 osnet.py
#   📄 repvgg.py
#   📄 resnest.py
#   📄 resnet.py
#   📄 resnext.py
#   📄 shufflenet.py
#   📄 vision_transformer.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling\backbones\regnet
#   📂 effnet
#   📂 regnetx
#   📂 regnety
#   📄 config.py
#   📄 effnet.py
#   📄 regnet.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling\backbones\regnet\effnet
#   📄 EN-B0_dds_8gpu.yaml
#   📄 EN-B1_dds_8gpu.yaml
#   📄 EN-B2_dds_8gpu.yaml
#   📄 EN-B3_dds_8gpu.yaml
#   📄 EN-B4_dds_8gpu.yaml
#   📄 EN-B5_dds_8gpu.yaml
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling\backbones\regnet\regnetx
#   📄 RegNetX-1.6GF_dds_8gpu.yaml
#   📄 RegNetX-12GF_dds_8gpu.yaml
#   📄 RegNetX-16GF_dds_8gpu.yaml
#   📄 RegNetX-200MF_dds_8gpu.yaml
#   📄 RegNetX-3.2GF_dds_8gpu.yaml
#   📄 RegNetX-32GF_dds_8gpu.yaml
#   📄 RegNetX-4.0GF_dds_8gpu.yaml
#   📄 RegNetX-400MF_dds_8gpu.yaml
#   📄 RegNetX-6.4GF_dds_8gpu.yaml
#   📄 RegNetX-600MF_dds_8gpu.yaml
#   📄 RegNetX-8.0GF_dds_8gpu.yaml
#   📄 RegNetX-800MF_dds_8gpu.yaml
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling\backbones\regnet\regnety
#   📄 RegNetY-1.6GF_dds_8gpu.yaml
#   📄 RegNetY-12GF_dds_8gpu.yaml
#   📄 RegNetY-16GF_dds_8gpu.yaml
#   📄 RegNetY-200MF_dds_8gpu.yaml
#   📄 RegNetY-3.2GF_dds_8gpu.yaml
#   📄 RegNetY-32GF_dds_8gpu.yaml
#   📄 RegNetY-4.0GF_dds_8gpu.yaml
#   📄 RegNetY-400MF_dds_8gpu.yaml
#   📄 RegNetY-6.4GF_dds_8gpu.yaml
#   📄 RegNetY-600MF_dds_8gpu.yaml
#   📄 RegNetY-8.0GF_dds_8gpu.yaml
#   📄 RegNetY-800MF_dds_8gpu.yaml
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling\heads
#   📄 build.py
#   📄 clas_head.py
#   📄 embedding_head.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling\losses
#   📄 circle_loss.py
#   📄 cross_entroy_loss.py
#   📄 focal_loss.py
#   📄 triplet_loss.py
#   📄 utils.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\modeling\meta_arch
#   📄 baseline.py
#   📄 build.py
#   📄 distiller.py
#   📄 mgn.py
#   📄 moco.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\solver
#   📂 optim
#   📄 build.py
#   📄 lr_scheduler.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\solver\optim
#   📄 lamb.py
#   📄 radam.py
#   📄 swa.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\fastreid\utils
#   📄 checkpoint.py
#   📄 collect_env.py
#   📄 comm.py
#   📄 compute_dist.py
#   📄 env.py
#   📄 events.py
#   📄 faiss_utils.py
#   📄 file_io.py
#   📄 history_buffer.py
#   📄 logger.py
#   📄 params.py
#   📄 precision_bn.py
#   📄 registry.py
#   📄 summary.py
#   📄 timer.py
#   📄 visualizer.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects
#   📂 CrossDomainReID
#   📂 DG-ReID
#   📂 FastAttr
#   📂 FastClas
#   📂 FastDistill
#   📂 FastFace
#   📂 FastRetri
#   📂 FastRT
#   📂 FastTune
#   📂 HAA
#   📂 NAIC20
#   📂 PartialReID
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\CrossDomainReID
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\DG-ReID
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastAttr
#   📂 configs
#   📂 fastattr
#   📄 README.md
#   📄 train_net.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastAttr\configs
#   📄 Base-attribute.yml
#   📄 dukemtmc.yml
#   📄 market1501.yml
#   📄 pa100.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastAttr\fastattr
#   📂 datasets
#   📂 modeling
#   📄 attr_dataset.py
#   📄 attr_evaluation.py
#   📄 config.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastAttr\fastattr\datasets
#   📄 bases.py
#   📄 dukemtmcattr.py
#   📄 market1501attr.py
#   📄 pa100k.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastAttr\fastattr\modeling
#   📄 attr_baseline.py
#   📄 attr_head.py
#   📄 bce_loss.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastClas
#   📂 configs
#   📂 fastclas
#   📄 README.md
#   📄 train_net.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastClas\configs
#   📄 base-clas.yaml
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastClas\fastclas
#   📄 bee_ant.py
#   📄 dataset.py
#   📄 trainer.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastDistill
#   📂 configs
#   📂 fastdistill
#   📄 README.md
#   📄 train_net.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastDistill\configs
#   📄 Base-kd.yml
#   📄 kd-sbs_r101ibn-sbs_r34.yml
#   📄 sbs_r101ibn.yml
#   📄 sbs_r34.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastDistill\fastdistill
#   📄 overhaul.py
#   📄 resnet_distill.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastFace
#   📂 configs
#   📂 fastface
#   📄 README.md
#   📄 train_net.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastFace\configs
#   📄 face_base.yml
#   📄 r101_ir.yml
#   📄 r50_ir.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastFace\fastface
#   📂 datasets
#   📂 modeling
#   📄 config.py
#   📄 face_data.py
#   📄 face_evaluator.py
#   📄 pfc_checkpointer.py
#   📄 trainer.py
#   📄 utils_amp.py
#   📄 verification.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastFace\fastface\datasets
#   📄 ms1mv2.py
#   📄 test_dataset.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastFace\fastface\modeling
#   📄 face_baseline.py
#   📄 face_head.py
#   📄 iresnet.py
#   📄 partial_fc.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRetri
#   📂 configs
#   📂 fastretri
#   📄 README.md
#   📄 train_net.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRetri\configs
#   📄 base-image_retri.yml
#   📄 cars.yml
#   📄 cub.yml
#   📄 inshop.yml
#   📄 sop.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRetri\fastretri
#   📄 config.py
#   📄 datasets.py
#   📄 retri_evaluator.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT
#   📂 demo
#   📂 docker
#   📂 fastrt
#   📂 include
#   📂 pybind_interface
#   📂 third_party
#   📂 tools
#   📄 CMakeLists.txt
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\demo
#   📄 CMakeLists.txt
#   📄 inference.cpp
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\docker
#   📂 trt7cu100
#   📂 trt7cu102
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\docker\trt7cu100
#   📄 Dockerfile
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\docker\trt7cu102
#   📄 Dockerfile
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\fastrt
#   📂 backbones
#   📂 common
#   📂 engine
#   📂 factory
#   📂 heads
#   📂 layers
#   📂 meta_arch
#   📄 CMakeLists.txt
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\fastrt\backbones
#   📄 CMakeLists.txt
#   📄 sbs_resnet.cpp
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\fastrt\common
#   📄 calibrator.cpp
#   📄 utils.cpp
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\fastrt\engine
#   📄 CMakeLists.txt
#   📄 InferenceEngine.cpp
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\fastrt\factory
#   📄 CMakeLists.txt
#   📄 factory.cpp
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\fastrt\heads
#   📄 CMakeLists.txt
#   📄 embedding_head.cpp
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\fastrt\layers
#   📄 CMakeLists.txt
#   📄 layers.cpp
#   📄 poolingLayerRT.cpp
#   📄 poolingLayerRT.h
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\fastrt\meta_arch
#   📄 baseline.cpp
#   📄 CMakeLists.txt
#   📄 model.cpp
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\include
#   📂 fastrt
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\include\fastrt
#   📄 baseline.h
#   📄 calibrator.h
#   📄 config.h.in
#   📄 cuda_utils.h
#   📄 embedding_head.h
#   📄 factory.h
#   📄 holder.h
#   📄 InferenceEngine.h
#   📄 IPoolingLayerRT.h
#   📄 layers.h
#   📄 logging.h
#   📄 model.h
#   📄 module.h
#   📄 sbs_resnet.h
#   📄 struct.h
#   📄 utils.h
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\pybind_interface
#   📂 docker
#   📄 CMakeLists.txt
#   📄 market_benchmark.py
#   📄 reid.cpp
#   📄 test.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\pybind_interface\docker
#   📂 trt7cu100
#   📂 trt7cu102_torch160
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\pybind_interface\docker\trt7cu100
#   📄 Dockerfile
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\pybind_interface\docker\trt7cu102_torch160
#   📄 Dockerfile
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\third_party
#   📂 cnpy
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\third_party\cnpy
#   📄 CMakeLists.txt
#   📄 cnpy.cpp
#   📄 cnpy.h
#   📄 example1.cpp
#   📄 LICENSE
#   📄 mat2npz
#   📄 npy2mat
#   📄 npz2mat
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastRT\tools
#   📄 gen_wts.py
#   📄 How_to_Generate.md
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastTune
#   📂 autotuner
#   📂 configs
#   📄 README.md
#   📄 tune_net.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastTune\autotuner
#   📄 tune_hooks.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\FastTune\configs
#   📄 search_trial.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\HAA
#   📄 Readme.md
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\NAIC20
#   📂 configs
#   📂 naic
#   📄 label.txt
#   📄 naic20r2_train_list_clean.txt
#   📄 README.md
#   📄 train_list_clean.txt
#   📄 train_net.py
#   📄 val_gallery.txt
#   📄 val_query.txt
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\NAIC20\configs
#   📄 Base-naic.yml
#   📄 nest101-base.yml
#   📄 r34-ibn.yml
#   📄 submit.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\NAIC20\naic
#   📄 config.py
#   📄 naic_dataset.py
#   📄 naic_evaluator.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\PartialReID
#   📂 configs
#   📂 partialreid
#   📄 README.md
#   📄 train_net.py
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\PartialReID\configs
#   📄 partial_market.yml
#
# 📁 .\DiffMOT-main\external\fast_reid\projects\PartialReID\partialreid
#   📄 config.py
#   📄 dsr_distance.py
#   📄 dsr_evaluation.py
#   📄 dsr_head.py
#   📄 partialbaseline.py
#   📄 partial_dataset.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\tests
#   📄 dataset_test.py
#   📄 feature_align.py
#   📄 interp_test.py
#   📄 lr_scheduler_test.py
#   📄 model_test.py
#   📄 sampler_test.py
#   📄 test_repvgg.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\tools
#   📂 deploy
#   📄 plain_train_net.py
#   📄 train_net.py
#
# 📁 .\DiffMOT-main\external\fast_reid\tools\deploy
#   📂 Caffe
#   📂 test_data
#   📄 caffe_export.py
#   📄 caffe_inference.py
#   📄 onnx_export.py
#   📄 onnx_inference.py
#   📄 pytorch_to_caffe.py
#   📄 README.md
#   📄 trt_calibrator.py
#   📄 trt_export.py
#   📄 trt_inference.py
#
# 📁 .\DiffMOT-main\external\fast_reid\tools\deploy\Caffe
#   📄 caffe.proto
#   📄 caffe_lmdb.py
#   📄 caffe_net.py
#   📄 caffe_pb2.py
#   📄 layer_param.py
#   📄 net.py
#   📄 ReadMe.md
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\fast_reid\tools\deploy\test_data
#   📄 0022_c6s1_002976_01.jpg
#   📄 0027_c2s2_091032_02.jpg
#   📄 0032_c6s1_002851_01.jpg
#   📄 0048_c1s1_005351_01.jpg
#   📄 0065_c6s1_009501_02.jpg
#
# 📁 .\DiffMOT-main\external\TrackEval
#   📂 docs
#   📂 scripts
#   📂 tests
#   📂 trackeval
#   📄 LICENSE
#   📄 minimum_requirements.txt
#   📄 pyproject.toml
#   📄 Readme.md
#   📄 requirements.txt
#   📄 setup.cfg
#   📄 setup.py
#
# 📁 .\DiffMOT-main\external\TrackEval\docs
#   📂 How_To
#   📂 MOTChallenge-Official
#   📂 OpenWorldTracking-Official
#   📂 RobMOTS-Official
#   📄 BDD100k-format.txt
#   📄 DAVIS-format.txt
#   📄 KITTI-format.txt
#   📄 MOTChallenge-format.txt
#   📄 MOTS-format.txt
#   📄 TAO-format.txt
#   📄 YouTube-VIS-format.txt
#
# 📁 .\DiffMOT-main\external\TrackEval\docs\How_To
#   📄 Add_a_new_metric.md
#
# 📁 .\DiffMOT-main\external\TrackEval\docs\MOTChallenge-Official
#   📄 Readme.md
#
# 📁 .\DiffMOT-main\external\TrackEval\docs\OpenWorldTracking-Official
#   📄 Readme.md
#
# 📁 .\DiffMOT-main\external\TrackEval\docs\RobMOTS-Official
#   📄 Readme.md
#
# 📁 .\DiffMOT-main\external\TrackEval\scripts
#   📄 comparison_plots.py
#   📄 run_bdd.py
#   📄 run_davis.py
#   📄 run_headtracking_challenge.py
#   📄 run_kitti.py
#   📄 run_kitti_mots.py
#   📄 run_mots_challenge.py
#   📄 run_mot_challenge.py
#   📄 run_rob_mots.py
#   📄 run_tao.py
#   📄 run_tao_ow.py
#   📄 run_youtube_vis.py
#
# 📁 .\DiffMOT-main\external\TrackEval\tests
#   📄 test_all_quick.py
#   📄 test_davis.py
#   📄 test_metrics.py
#   📄 test_mot17.py
#   📄 test_mots.py
#
# 📁 .\DiffMOT-main\external\TrackEval\trackeval
#   📂 baselines
#   📂 datasets
#   📂 metrics
#   📄 eval.py
#   📄 plotting.py
#   📄 utils.py
#   📄 _timing.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\TrackEval\trackeval\baselines
#   📄 baseline_utils.py
#   📄 non_overlap.py
#   📄 pascal_colormap.py
#   📄 stp.py
#   📄 thresholder.py
#   📄 vizualize.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\TrackEval\trackeval\datasets
#   📄 bdd100k.py
#   📄 davis.py
#   📄 head_tracking_challenge.py
#   📄 kitti_2d_box.py
#   📄 kitti_mots.py
#   📄 mots_challenge.py
#   📄 mot_challenge_2d_box.py
#   📄 rob_mots.py
#   📄 rob_mots_classmap.py
#   📄 run_rob_mots.py
#   📄 tao.py
#   📄 tao_ow.py
#   📄 youtube_vis.py
#   📄 _base_dataset.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\TrackEval\trackeval\metrics
#   📄 clear.py
#   📄 count.py
#   📄 hota.py
#   📄 identity.py
#   📄 ideucl.py
#   📄 j_and_f.py
#   📄 track_map.py
#   📄 vace.py
#   📄 _base_metric.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX
#   📂 .github
#   📂 assets
#   📂 demo
#   📂 docs
#   📂 exps
#   📂 tests
#   📂 tools
#   📂 yolox
#   📄 .pre-commit-config.yaml
#   📄 .readthedocs.yaml
#   📄 hubconf.py
#   📄 LICENSE
#   📄 MANIFEST.in
#   📄 README.md
#   📄 requirements.txt
#   📄 setup.cfg
#   📄 setup.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\.github
#   📂 workflows
#
# 📁 .\DiffMOT-main\external\YOLOX\.github\workflows
#   📄 ci.yaml
#   📄 format_check.sh
#
# 📁 .\DiffMOT-main\external\YOLOX\assets
#   📄 demo.png
#   📄 dog.jpg
#   📄 git_fig.png
#   📄 logo.png
#   📄 sunjian.png
#
# 📁 .\DiffMOT-main\external\YOLOX\demo
#   📂 MegEngine
#   📂 ncnn
#   📂 ONNXRuntime
#   📂 OpenVINO
#   📂 TensorRT
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\MegEngine
#   📂 cpp
#   📂 python
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\MegEngine\cpp
#   📄 build.sh
#   📄 README.md
#   📄 yolox.cpp
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\MegEngine\python
#   📂 models
#   📄 build.py
#   📄 convert_weights.py
#   📄 demo.py
#   📄 dump.py
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\MegEngine\python\models
#   📄 darknet.py
#   📄 network_blocks.py
#   📄 yolox.py
#   📄 yolo_fpn.py
#   📄 yolo_head.py
#   📄 yolo_pafpn.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn
#   📂 android
#   📂 cpp
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android
#   📂 app
#   📂 gradle
#   📄 build.gradle
#   📄 gradlew
#   📄 gradlew.bat
#   📄 README.md
#   📄 settings.gradle
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app
#   📂 src
#   📄 build.gradle
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src
#   📂 main
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main
#   📂 assets
#   📂 java
#   📂 jni
#   📂 res
#   📄 AndroidManifest.xml
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\assets
#   📄 yolox.param
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\java
#   📂 com
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\java\com
#   📂 megvii
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\java\com\megvii
#   📂 yoloXncnn
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\java\com\megvii\yoloXncnn
#   📄 MainActivity.java
#   📄 yoloXncnn.java
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\jni
#   📄 CMakeLists.txt
#   📄 yoloXncnn_jni.cpp
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\res
#   📂 layout
#   📂 values
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\res\layout
#   📄 main.xml
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\app\src\main\res\values
#   📄 strings.xml
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\gradle
#   📂 wrapper
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\android\gradle\wrapper
#   📄 gradle-wrapper.jar
#   📄 gradle-wrapper.properties
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ncnn\cpp
#   📄 README.md
#   📄 yolox.cpp
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\ONNXRuntime
#   📄 onnx_inference.py
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\OpenVINO
#   📂 cpp
#   📂 python
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\OpenVINO\cpp
#   📄 CMakeLists.txt
#   📄 README.md
#   📄 yolox_openvino.cpp
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\OpenVINO\python
#   📄 openvino_inference.py
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\TensorRT
#   📂 cpp
#   📂 python
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\TensorRT\cpp
#   📄 CMakeLists.txt
#   📄 logging.h
#   📄 README.md
#   📄 yolox.cpp
#
# 📁 .\DiffMOT-main\external\YOLOX\demo\TensorRT\python
#   📄 README.md
#
# 📁 .\DiffMOT-main\external\YOLOX\docs
#   📂 demo
#   📂 _static
#   📄 conf.py
#   📄 freeze_module.md
#   📄 index.rst
#   📄 Makefile
#   📄 manipulate_training_image_size.md
#   📄 model_zoo.md
#   📄 quick_run.md
#   📄 requirements-doc.txt
#   📄 train_custom_data.md
#   📄 updates_note.md
#
# 📁 .\DiffMOT-main\external\YOLOX\docs\demo
#   📄 megengine_cpp_readme.md
#   📄 megengine_py_readme.md
#   📄 ncnn_android_readme.md
#   📄 ncnn_cpp_readme.md
#   📄 onnx_readme.md
#   📄 openvino_cpp_readme.md
#   📄 openvino_py_readme.md
#   📄 trt_cpp_readme.md
#   📄 trt_py_readme.md
#
# 📁 .\DiffMOT-main\external\YOLOX\docs\_static
#   📂 css
#
# 📁 .\DiffMOT-main\external\YOLOX\docs\_static\css
#   📄 custom.css
#
# 📁 .\DiffMOT-main\external\YOLOX\exps
#   📂 dancetrack
#   📂 default
#   📂 example
#   📂 mot
#   📂 sportsmot
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\dancetrack
#   📂 __pycache__
#   📄 yolox_l_mix_det.py
#   📄 yolox_m_mix_det.py
#   📄 yolox_s_mix_det.py
#   📄 yolox_x.py
#   📄 yolox_x_ch.py
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\dancetrack\__pycache__
#   📄 yolox_l_mix_det.cpython-38.pyc
#   📄 yolox_m_mix_det.cpython-38.pyc
#   📄 yolox_s_mix_det.cpython-38.pyc
#   📄 yolox_x.cpython-38.pyc
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\default
#   📄 yolov3.py
#   📄 yolox_l.py
#   📄 yolox_m.py
#   📄 yolox_nano.py
#   📄 yolox_s.py
#   📄 yolox_tiny.py
#   📄 yolox_x.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\example
#   📂 custom
#   📂 yolox_voc
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\example\custom
#   📄 nano.py
#   📄 yolox_s.py
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\example\yolox_voc
#   📄 yolox_voc_s.py
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\mot
#   📂 __pycache__
#   📄 yolox_l_mix_det.py
#   📄 yolox_m_mix_det.py
#   📄 yolox_s_mix_det.py
#   📄 yolox_x_ablation.py
#   📄 yolox_x_ch.py
#   📄 yolox_x_mix_det.py
#   📄 yolox_x_mix_mot20_ch.py
#   📄 yolox_x_mot17_half.py
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\mot\__pycache__
#   📄 yolox_s_mix_det.cpython-38.pyc
#   📄 yolox_x_mix_det.cpython-38.pyc
#   📄 yolox_x_mix_mot20_ch.cpython-38.pyc
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\sportsmot
#   📂 __pycache__
#   📄 yolox_x.py
#   📄 yolox_x_ch.py
#   📄 yolox_x_dancetrack.py
#   📄 yolox_x_soccernet.py
#   📄 yolox_x_sportsmot.py
#   📄 yolox_x_sportsmot_mix.py
#
# 📁 .\DiffMOT-main\external\YOLOX\exps\sportsmot\__pycache__
#   📄 yolox_x.cpython-38.pyc
#   📄 yolox_x_sportsmot_mix.cpython-38.pyc
#
# 📁 .\DiffMOT-main\external\YOLOX\tests
#   📂 utils
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\tests\utils
#   📄 test_model_utils.py
#
# 📁 .\DiffMOT-main\external\YOLOX\tools
#   📄 demo.py
#   📄 eval.py
#   📄 export_onnx.py
#   📄 export_torchscript.py
#   📄 train.py
#   📄 trt.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox
#   📂 core
#   📂 data
#   📂 evaluators
#   📂 exp
#   📂 layers
#   📂 models
#   📂 tools
#   📂 utils
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\core
#   📄 launch.py
#   📄 trainer.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\data
#   📂 datasets
#   📄 dataloading.py
#   📄 data_augment.py
#   📄 data_prefetcher.py
#   📄 samplers.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\data\datasets
#   📄 coco.py
#   📄 coco_classes.py
#   📄 datasets_wrapper.py
#   📄 mosaicdetection.py
#   📄 voc.py
#   📄 voc_classes.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\evaluators
#   📄 coco_evaluator.py
#   📄 voc_eval.py
#   📄 voc_evaluator.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\exp
#   📂 default
#   📄 base_exp.py
#   📄 build.py
#   📄 yolox_base.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\exp\default
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\layers
#   📂 cocoeval
#   📄 fast_coco_eval_api.py
#   📄 jit_ops.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\layers\cocoeval
#   📄 cocoeval.cpp
#   📄 cocoeval.h
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\models
#   📄 build.py
#   📄 darknet.py
#   📄 losses.py
#   📄 network_blocks.py
#   📄 yolox.py
#   📄 yolo_fpn.py
#   📄 yolo_head.py
#   📄 yolo_pafpn.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\tools
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\external\YOLOX\yolox\utils
#   📄 allreduce_norm.py
#   📄 boxes.py
#   📄 checkpoint.py
#   📄 compat.py
#   📄 demo_utils.py
#   📄 dist.py
#   📄 ema.py
#   📄 logger.py
#   📄 lr_scheduler.py
#   📄 metric.py
#   📄 model_utils.py
#   📄 setup_env.py
#   📄 visualize.py
#   📄 __init__.py
#
# 📁 .\DiffMOT-main\models
#   📂 __pycache__
#   📄 autoencoder.py
#   📄 common.py
#   📄 condition_embedding.py
#   📄 denoising_diffusion_pytorch.py
#   📄 diffusion.py
#
# 📁 .\DiffMOT-main\models\__pycache__
#   📄 autoencoder.cpython-37.pyc
#   📄 common.cpython-37.pyc
#   📄 condition_embedding.cpython-37.pyc
#   📄 diffusion.cpython-37.pyc
#
# 📁 .\DiffMOT-main\tracker
#   📂 ocsort_tracker
#   📂 __pycache__
#   📄 basetrack.py
#   📄 cmc.py
#   📄 DiffMOTtracker.py
#   📄 embedding.py
#   📄 gmc.py
#   📄 matching.py
#
# 📁 .\DiffMOT-main\tracker\ocsort_tracker
#   📂 __pycache__
#   📄 association.py
#   📄 kalmanfilter.py
#   📄 ocsort.py
#
# 📁 .\DiffMOT-main\tracker\ocsort_tracker\__pycache__
#   📄 association.cpython-37.pyc
#   📄 association.cpython-38.pyc
#   📄 kalmanfilter.cpython-37.pyc
#   📄 kalmanfilter.cpython-38.pyc
#   📄 ocsort.cpython-37.pyc
#   📄 ocsort.cpython-38.pyc
#
# 📁 .\DiffMOT-main\tracker\__pycache__
#   📄 basetrack.cpython-37.pyc
#   📄 basetrack.cpython-38.pyc
#   📄 byte_tracker.cpython-37.pyc
#   📄 byte_tracker.cpython-38.pyc
#   📄 byte_tracker_diff.cpython-37.pyc
#   📄 byte_tracker_oc.cpython-37.pyc
#   📄 byte_tracker_reid.cpython-37.pyc
#   📄 byte_tracker_reid.cpython-38.pyc
#   📄 byte_tracker_reid_demo.cpython-37.pyc
#   📄 cmc.cpython-37.pyc
#   📄 DiffMOTtracker.cpython-37.pyc
#   📄 embedding.cpython-37.pyc
#   📄 gmc.cpython-37.pyc
#   📄 matching.cpython-37.pyc
#   📄 matching.cpython-38.pyc
#   📄 multitracker.cpython-37.pyc
#   📄 multitracker_demo.cpython-37.pyc
#   📄 multitracker_diff.cpython-37.pyc
#   📄 multitracker_diff_delt.cpython-37.pyc
#   📄 multitracker_diff_longterm.cpython-37.pyc
#   📄 multitracker_diff_longterm_all.cpython-37.pyc
#   📄 multitracker_diff_longterm_byte.cpython-37.pyc
#   📄 multitracker_diff_longterm_cmc.cpython-37.pyc
#   📄 multitracker_diff_longterm_cmc_tp.cpython-37.pyc
#   📄 multitracker_diff_longterm_emb.cpython-37.pyc
#   📄 multitracker_diff_longterm_emb_byte.cpython-37.pyc
#   📄 multitracker_diff_longterm_emb_byte2.cpython-37.pyc
#   📄 multitracker_diff_longterm_emb_byte2_kf.cpython-37.pyc
#   📄 multitracker_diff_longterm_emb_byte_post.cpython-37.pyc
#   📄 multitracker_diff_longterm_emb_byte_postdelt.cpython-37.pyc
#   📄 multitracker_diff_longterm_iou.cpython-37.pyc
#   📄 multitracker_diff_longterm_pre.cpython-37.pyc
#   📄 multitracker_iou.cpython-37.pyc
#   📄 multitracker_oc.cpython-37.pyc
#   📄 multitracker_vis.cpython-37.pyc
#   📄 multitracker_vis_byte.cpython-37.pyc
#
# 📁 .\DiffMOT-main\tracking_utils
#   📂 __pycache__
#   📄 evaluation.py
#   📄 io.py
#   📄 kalman_filter.py
#   📄 log.py
#   📄 nms.py
#   📄 NSA_kalman_filter.py
#   📄 parse_config.py
#   📄 timer.py
#   📄 utils.py
#   📄 visualization.py
#
# 📁 .\DiffMOT-main\tracking_utils\__pycache__
#   📄 evaluation.cpython-37.pyc
#   📄 evaluation.cpython-38.pyc
#   📄 io.cpython-37.pyc
#   📄 io.cpython-38.pyc
#   📄 kalman_filter.cpython-37.pyc
#   📄 kalman_filter.cpython-38.pyc
#   📄 log.cpython-37.pyc
#   📄 log.cpython-38.pyc
#   📄 NSA_kalman_filter.cpython-37.pyc
#   📄 timer.cpython-37.pyc
#   📄 timer.cpython-38.pyc
#   📄 utils.cpython-37.pyc
#   📄 utils.cpython-38.pyc
#   📄 visualization.cpython-37.pyc
#   📄 visualization.cpython-38.pyc
#
# 📁 .\DiffMOT-main\__pycache__
#   📄 diffmot.cpython-37.pyc
#   📄 diffmot_longterm_emb.cpython-37.pyc

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\vansh\VANSHIKASOHAL
# ['.ipynb_checkpoints', 'CODEFILE.ipynb', 'DiffMOT-main', 'Untitled11.ipynb']

# %%
print(os.listdir("DiffMOT-main"))
# Out:
# ['.idea', '.ipynb_checkpoints', 'assets', 'configs', 'dancetrack_data_process.py', 'dataset', 'diffmot.py', 'experiments', 'external', 'LICENSE', 'main.py', 'models', 'mot_data_process.py', 'New folder', 'pretrained', 'README.md', 'requirement.txt', 'sports_data_process.py', 'tracker', 'tracking_utils', '__pycache__']

# %%
import os

os.makedirs("cython_bbox", exist_ok=True)

with open("cython_bbox/__init__.py", "w") as f:
    f.write("""
import numpy as np

def bbox_overlaps(boxes1, boxes2):
    overlaps = np.zeros((len(boxes1), len(boxes2)), dtype=np.float32)
    for i, box1 in enumerate(boxes1):
        x1, y1, x2, y2 = box1
        area1 = (x2 - x1) * (y2 - y1)

        for j, box2 in enumerate(boxes2):
            xx1 = max(x1, box2[0])
            yy1 = max(y1, box2[1])
            xx2 = min(x2, box2[2])
            yy2 = min(y2, box2[3])

            w = max(0, xx2 - xx1)
            h = max(0, yy2 - yy1)
            inter = w * h

            area2 = (box2[2] - box2[0]) * (box2[3] - box2[1])
            union = area1 + area2 - inter

            overlaps[i, j] = inter / union if union > 0 else 0

    return overlaps
""")

print("Dummy cython_bbox module created!")
# Out:
# Dummy cython_bbox module created!

# %%
# !pip install torchreid
# Out:
# Collecting torchreid
#   Downloading torchreid-0.2.5.tar.gz (92 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: torchreid
#   Building wheel for torchreid (pyproject.toml): started
#   Building wheel for torchreid (pyproject.toml): finished with status 'done'
#   Created wheel for torchreid: filename=torchreid-0.2.5-py3-none-any.whl size=144441 sha256=fb87f0d43160c8f64be293d09d5af0fd3ea4cd4b7b4c74dd0ed35b2440d32a83
#   Stored in directory: c:\users\rajes\appdata\local\pip\cache\wheels\61\dc\08\b478469bab07b5ede9e962968ebe3c8961c10c5fc106a6c697
# Successfully built torchreid
# Installing collected packages: torchreid
# Successfully installed torchreid-0.2.5
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install easydict
# Out:
# Collecting easydict
#   Using cached easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# Using cached easydict-1.13-py3-none-any.whl (6.8 kB)
# Installing collected packages: easydict
# Successfully installed easydict-1.13
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os 
import yaml
config["eval_expname"]=" "

# %%
import os
path="petrained/motion/MOT_epoch800.pt"
print("Exist:",os.path.exists(path))
print("Full path",os.path.abspath(path))
# Out:
# Exist: False
# Full path C:\Users\rajes\VANSHIKASOHAL\DiffMOT-main\petrained\motion\MOT_epoch800.pt

# %%
import urllib.request
import os

os.makedirs("pretrained/motion", exist_ok=True)

url = "https://github.com/Kroery/DiffMOT/releases/download/v1.0/MOT_epoch800.pt"
path = "pretrained/motion/MOT_epoch800.pt"

urllib.request.urlretrieve(url, path)

print("Downloaded successfully!")
# Out:
# Downloaded successfully!

# %%
import urllib.request
import os

os.makedirs("pretrained/motion", exist_ok=True)

url = "https://github.com/Kroery/DiffMOT/releases/download/v1.0/MOT_epoch800.pt"
path = "pretrained/motion/MOT_epoch800.pt"

urllib.request.urlretrieve(url, path)

print("Downloaded successfully!")
import os
path="pretrained/motion/MOT_epoch800.pt"
print("Exist:", os.path.exists(path))
print("Full path:", os.path.abspath(path))
import urllib.request
import os

os.makedirs("pretrained/motion", exist_ok=True)

url = "https://github.com/Kroery/DiffMOT/releases/download/v1.0/MOT_epoch800.pt"
path = "pretrained/motion/MOT_epoch800.pt"

try:
    urllib.request.urlretrieve(url, path)
    if os.path.exists(path):
        print("Download verified")
    else:
        print("Download failed")
except Exception as e:
    print("Error:", e)
import requests

url = "https://github.com/Kroery/DiffMOT/releases/download/v1.0/MOT_epoch800.pt"
path = "pretrained/motion/MOT_epoch800.pt"

response = requests.get(url, stream=True)
with open(path, "wb") as f:
    for chunk in response.iter_content(chunk_size=8192):
        if chunk:
            f.write(chunk)

print("Done. Exists:", os.path.exists(path))
# Out:
# Downloaded successfully!
# Exist: True
# Full path: C:\Users\rajes\VANSHIKASOHAL\DiffMOT-main\pretrained\motion\MOT_epoch800.pt
# Download verified
# Done. Exists: True

# %%
import os

path = "pretrained/motion/MOT_epoch800.pt"
print("File size (MB):", os.path.getsize(path) / (1024*1024))
# Out:
# File size (MB): 168.32483386993408

# %%
import os
print(os.listdir("models"))
# Out:
# ['autoencoder.py', 'common.py', 'condition_embedding.py', 'denoising_diffusion_pytorch.py', 'diffusion.py', '__pycache__']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\vansh\VANSHIKASOHAL

# %%
os.chdir("DiffMOT-main")
print(os.getcwd())
# Out:
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main

# %%
# !pip install torch torchvision torchaudio
# !pip install ultralytics
# !pip install tensorboardX lap motmetrics scipy opencv-python tqdm matplotlib scikit-learn filterpy torchreid gdown
# Out:
# Requirement already satisfied: torch in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.10.0)
# Requirement already satisfied: torchvision in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.25.0)
# Requirement already satisfied: torchaudio in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.11.0)
# Requirement already satisfied: filelock in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (2026.1.0)
# Requirement already satisfied: setuptools in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch) (82.0.1)
# Requirement already satisfied: numpy in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torchvision) (2.4.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torchvision) (12.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: ultralytics in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (8.4.11)
# Requirement already satisfied: numpy>=1.23.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (2.4.2)
# Requirement already satisfied: matplotlib>=3.3.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (4.13.0.90)
# Requirement already satisfied: pillow>=7.1.2 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (1.17.0)
# Requirement already satisfied: torch>=1.8.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (1.37.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.37.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from polars>=0.20.0->ultralytics) (1.37.1)
# Requirement already satisfied: six>=1.5 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.8.0->ultralytics) (2026.1.0)
# Requirement already satisfied: setuptools in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.8.0->ultralytics) (82.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: tensorboardX in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.6.5)
# Requirement already satisfied: lap in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.5.13)
# Requirement already satisfied: motmetrics in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.4.0)
# Requirement already satisfied: scipy in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.17.0)
# Requirement already satisfied: opencv-python in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.13.0.90)
# Requirement already satisfied: tqdm in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.67.2)
# Requirement already satisfied: matplotlib in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.10.8)
# Requirement already satisfied: scikit-learn in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.8.0)
# Requirement already satisfied: filterpy in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.4.5)
# Requirement already satisfied: torchreid in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.2.5)
# Requirement already satisfied: gdown in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (5.2.1)
# Requirement already satisfied: numpy in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorboardX) (2.4.2)
# Requirement already satisfied: packaging in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorboardX) (26.0)
# Requirement already satisfied: protobuf>=3.20 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorboardX) (7.34.1)
# Requirement already satisfied: pandas>=0.23.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from motmetrics) (3.0.0)
# Requirement already satisfied: xmltodict>=0.12.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from motmetrics) (1.0.4)
# Requirement already satisfied: colorama in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gdown) (3.20.3)
# Requirement already satisfied: requests[socks] in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tzdata in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=0.23.1->motmetrics) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests[socks]->gdown) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests[socks]->gdown) (2026.1.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests[socks]->gdown) (1.7.1)

# %%
import os

paths = [
    "pretrained/motion/MOT_epoch800.pt",
    "pretrained/reid/mot17_sbs_S50.pth",
    "datasets/mot/train"
]

for p in paths:
    print(p, "→", os.path.exists(p))
# Out:
# pretrained/motion/MOT_epoch800.pt → False
# pretrained/reid/mot17_sbs_S50.pth → False
# datasets/mot/train → False

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main
# ['.idea', '.ipynb_checkpoints', 'assets', 'configs', 'dancetrack_data_process.py', 'dataset', 'diffmot.py', 'external', 'LICENSE', 'main.py', 'models', 'mot_data_process.py', 'README.md', 'requirement.txt', 'sports_data_process.py', 'tracker', 'tracking_utils', '__pycache__']

# %%
import os

print("pretrained exists:", os.path.exists("pretrained"))
print("datasets exists:", os.path.exists("datasets"))
# Out:
# pretrained exists: False
# datasets exists: False

# %%
import os
os.listdir()
# Out:
# ['.idea',
#  'assets',
#  'configs',
#  'cython_bbox',
#  'dancetrack_data_process.py',
#  'dataset',
#  'datasets',
#  'diffmot.py',
#  'experiments',
#  'external',
#  'LICENSE',
#  'main.py',
#  'models',
#  'mot_data_process.py',
#  'pretrained',
#  'README.md',
#  'requirement.txt',
#  'sports_data_process.py',
#  'tracker',
#  'tracking_utils',
#  'yolov8n.pt',
#  '__pycache__']

# %%
# !python  main.py
# Out:
# > Train Dataset built!
# 2026-04-07 19:57:37 [DEBUG]: matplotlib data path: C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\mpl-data
# 2026-04-07 19:57:37 [DEBUG]: CONFIGDIR=C:\Users\rajes\.matplotlib
# 2026-04-07 19:57:37 [DEBUG]: interactive is False
# 2026-04-07 19:57:37 [DEBUG]: platform is win32
# 2026-04-07 19:57:37 [DEBUG]: CACHEDIR=C:\Users\rajes\.matplotlib
# 2026-04-07 19:57:37 [DEBUG]: Using fontManager instance from C:\Users\rajes\.matplotlib\fontlist-v390.json
# C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchreid\reid\metrics\rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775572059.319330   15096 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-07 19:57:40 [DEBUG]: Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2026-04-07 19:57:40 [DEBUG]: Creating converter from 7 to 5
# 2026-04-07 19:57:40 [DEBUG]: Creating converter from 5 to 7
# 2026-04-07 19:57:40 [DEBUG]: Creating converter from 7 to 5
# 2026-04-07 19:57:40 [DEBUG]: Creating converter from 5 to 7
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775572060.821136   15096 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Traceback (most recent call last):
#   File "C:\Users\rajes\VANSHIKASOHAL\DiffMOT-main\main.py", line 33, in <module>
#     main()
#   File "C:\Users\rajes\VANSHIKASOHAL\DiffMOT-main\main.py", line 16, in main
#     with open(args.config) as f:
#          ^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
pip install -r requirement.txt
# Out:
# Collecting einops (from -r requirement.txt (line 1))
#   Downloading einops-0.8.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pyyaml in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from -r requirement.txt (line 2)) (6.0.3)
# Collecting argparse (from -r requirement.txt (line 3))
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting easydict (from -r requirement.txt (line 4))
#   Downloading easydict-1.13-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from -r requirement.txt (line 5)) (2.4.2)
# Requirement already satisfied: tensorboardX in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from -r requirement.txt (line 6)) (2.6.5)
# Requirement already satisfied: tqdm in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from -r requirement.txt (line 7)) (4.67.2)
# Requirement already satisfied: opencv-python in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from -r requirement.txt (line 8)) (4.13.0.90)
# Requirement already satisfied: scipy in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from -r requirement.txt (line 9)) (1.17.0)
# Requirement already satisfied: lap in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from -r requirement.txt (line 10)) (0.5.13)
# Requirement already satisfied: cython in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from -r requirement.txt (line 11)) (3.2.4)
# Collecting cython-bbox (from -r requirement.txt (line 12))
#   Using cached cython_bbox-0.1.5.tar.gz (4.4 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fvcore (from -r requirement.txt (line 13))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: packaging in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorboardX->-r requirement.txt (line 6)) (26.0)
# Requirement already satisfied: protobuf>=3.20 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tensorboardX->-r requirement.txt (line 6)) (7.34.1)
# Requirement already satisfied: colorama in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm->-r requirement.txt (line 7)) (0.4.6)
# Collecting yacs>=0.1.6 (from fvcore->-r requirement.txt (line 13))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Collecting termcolor>=1.1 (from fvcore->-r requirement.txt (line 13))
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: Pillow in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fvcore->-r requirement.txt (line 13)) (12.1.0)
# Requirement already satisfied: tabulate in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fvcore->-r requirement.txt (line 13)) (0.10.0)
# Collecting iopath>=0.1.7 (from fvcore->-r requirement.txt (line 13))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: typing_extensions in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from iopath>=0.1.7->fvcore->-r requirement.txt (line 13)) (4.15.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore->-r requirement.txt (line 13))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting pywin32>=226 (from portalocker->iopath>=0.1.7->fvcore->-r requirement.txt (line 13))
#   Downloading pywin32-311-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Downloading einops-0.8.2-py3-none-any.whl (65 kB)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Downloading easydict-1.13-py3-none-any.whl (6.8 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading pywin32-311-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.5 MB 5.7 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.5 MB 6.3 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.5 MB 6.5 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.5 MB 6.1 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.5 MB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 7.9/9.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 6.2 MB/s  0:00:01
# Building wheels for collected packages: cython-bbox, fvcore, iopath
#   Building wheel for cython-bbox (pyproject.toml): started
#   Building wheel for cython-bbox (pyproject.toml): finished with status 'error'
#   Building wheel for fvcore (pyproject.toml): started
#   Building wheel for fvcore (pyproject.toml): finished with status 'done'
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61445 sha256=2eaa5d33fab239b5ad45887c5d54c8d9130efc0f7a5fdc3016ddfb49ee198da5
#   Stored in directory: c:\users\vansh\appdata\local\pip\cache\wheels\6b\1b\9a\9f4843148961a522f56dbeaa5543071ac2389d9a079ec724ab
#   Building wheel for iopath (pyproject.toml): started
#   Building wheel for iopath (pyproject.toml): finished with status 'done'
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31606 sha256=dda5722c502eb40f11b691e96db62ac78d1952e3c1b834ca7c54be65fdd7012f
#   Stored in directory: c:\users\vansh\appdata\local\pip\cache\wheels\cd\c4\19\776124f304c8d9cb940cb164ec2ad635b42d9d1cf03217506d
# Successfully built fvcore iopath
# Failed to build cython-bbox
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Building wheel for cython-bbox (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   Compiling src/cython_bbox.pyx because it changed.
#   [1/1] Cythonizing src/cython_bbox.pyx
#   building 'cython_bbox' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for cython-bbox
# error: failed-wheel-build-for-install
#
# Failed to build installable wheels for some pyproject.toml based projects
#
# cython-bbox

# %%
import os
print(os.listdir("dataset"))
# Out:
# ['.ipynb_checkpoints', 'dataset.py', '__init__.py', '__pycache__']

# %%
import os

for root, dirs, files in os.walk("."):
    if "det.txt" in files:
        print(root)

# %%
#new
import os

model_path = "pretrained/motion/MOT_epoch800.pt"

print("Model exists:", os.path.exists(model_path))

# list pretrained folder
print("\nFiles in pretrained/motion:")
print(os.listdir("pretrained/motion"))
# Out:
# Model exists: True
#
# Files in pretrained/motion:
# ['MOT_epoch800.pt']

# %%
import os

os.makedirs("pretrained/motion", exist_ok=True)
os.makedirs("pretrained/reid", exist_ok=True)

# Motion model
os.system('curl -L -o pretrained/motion/MOT_epoch800.pt https://github.com/Kroery/DiffMOT/releases/download/v1.0/MOT_epoch800.pt')

# ReID model
os.system('curl -L -o pretrained/reid/mot17_sbs_S50.pth https://github.com/Kroery/DiffMOT/releases/download/v1.0/mot17_sbs_S50.pth')

# %%
import torch

path = "pretrained/motion/MOT_epoch800.pt"

model = torch.load(path, map_location="cpu")
print("Model loaded successfully!")
print(type(model))
# Out:
# Model loaded successfully!
# <class 'dict'>

# %%
# !pip install einops
# Out:
# Collecting einops
#   Using cached einops-0.8.2-py3-none-any.whl.metadata (13 kB)
# Using cached einops-0.8.2-py3-none-any.whl (65 kB)
# Installing collected packages: einops
# Successfully installed einops-0.8.2
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install cython_bbox
# Out:
# Collecting cython_bbox
#   Using cached cython_bbox-0.1.5.tar.gz (4.4 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: Cython in c:\users\vansh\diffmot_env\lib\site-packages (from cython_bbox) (3.2.4)
# Requirement already satisfied: numpy in c:\users\vansh\diffmot_env\lib\site-packages (from cython_bbox) (2.4.4)
# Building wheels for collected packages: cython_bbox
#   Building wheel for cython_bbox (pyproject.toml): started
#   Building wheel for cython_bbox (pyproject.toml): finished with status 'error'
# Failed to build cython_bbox
#   error: subprocess-exited-with-error
#
#   Building wheel for cython_bbox (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   Compiling src/cython_bbox.pyx because it changed.
#   [1/1] Cythonizing src/cython_bbox.pyx
#   building 'cython_bbox' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for cython_bbox
# ERROR: Could not build wheels for cython_bbox, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\vansh\diffmot_env\Scripts\python.exe

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main
# ['.idea', '.ipynb_checkpoints', 'assets', 'configs', 'dancetrack_data_process.py', 'dataset', 'datasets', 'diffmot.py', 'experiments', 'external', 'LICENSE', 'main.py', 'models', 'mot_data_process.py', 'pretrained', 'README.md', 'requirement.txt', 'sports_data_process.py', 'tracker', 'tracking_utils', '__pycache__']

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-6.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\vansh\diffmot_env\lib\site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in c:\users\vansh\diffmot_env\lib\site-packages (from gdown) (3.25.2)
# Requirement already satisfied: requests[socks] in c:\users\vansh\diffmot_env\lib\site-packages (from gdown) (2.33.1)
# Requirement already satisfied: tqdm in c:\users\vansh\diffmot_env\lib\site-packages (from gdown) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.0 in c:\users\vansh\diffmot_env\lib\site-packages (from gdown) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\vansh\diffmot_env\lib\site-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vansh\diffmot_env\lib\site-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vansh\diffmot_env\lib\site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\vansh\diffmot_env\lib\site-packages (from requests[socks]->gdown) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\vansh\diffmot_env\lib\site-packages (from requests[socks]->gdown) (2026.2.25)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\vansh\diffmot_env\lib\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-6.0.0-py3-none-any.whl (18 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: PySocks, gdown
# Successfully installed PySocks-1.7.1 gdown-6.0.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tensorboard
# Out:
# Collecting tensorboard
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.80.0-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Using cached markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\vansh\diffmot_env\lib\site-packages (from tensorboard) (2.4.4)
# Requirement already satisfied: packaging in c:\users\vansh\diffmot_env\lib\site-packages (from tensorboard) (26.0)
# Requirement already satisfied: pillow in c:\users\vansh\diffmot_env\lib\site-packages (from tensorboard) (12.1.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\vansh\diffmot_env\lib\site-packages (from tensorboard) (7.34.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\vansh\diffmot_env\lib\site-packages (from tensorboard) (65.5.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\vansh\diffmot_env\lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\vansh\diffmot_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading grpcio-1.80.0-cp311-cp311-win_amd64.whl (4.9 MB)
#    ---------------------------------------- 0.0/4.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.9 MB ? eta -:--:--
#    - -------------------------------------- 0.2/4.9 MB 6.3 MB/s eta 0:00:01
#    -- ------------------------------------- 0.4/4.9 MB 4.5 MB/s eta 0:00:02
#    --- ------------------------------------ 0.4/4.9 MB 3.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/4.9 MB 3.2 MB/s eta 0:00:02
#    ------- -------------------------------- 0.9/4.9 MB 4.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.3/4.9 MB 4.7 MB/s eta 0:00:01
#    -------------- ------------------------- 1.7/4.9 MB 5.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.1/4.9 MB 5.8 MB/s eta 0:00:01
#    -------------------- ------------------- 2.5/4.9 MB 6.2 MB/s eta 0:00:01
#    ------------------------ --------------- 3.0/4.9 MB 6.6 MB/s eta 0:00:01
#    --------------------------- ------------ 3.4/4.9 MB 6.9 MB/s eta 0:00:01
#    -------------------------------- ------- 3.9/4.9 MB 7.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.3/4.9 MB 7.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.5/4.9 MB 7.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.5/4.9 MB 7.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.5/4.9 MB 7.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.5/4.9 MB 7.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.5/4.9 MB 7.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.5/4.9 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  4.9/4.9 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.9/4.9 MB 5.3 MB/s eta 0:00:00
# Using cached markdown-3.10.2-py3-none-any.whl (108 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.5 kB ? eta -:--:--
#    ---------------------------------------- 226.5/226.5 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: werkzeug, tensorboard-data-server, markdown, grpcio, absl-py, tensorboard
# Successfully installed absl-py-2.4.0 grpcio-1.80.0 markdown-3.10.2 tensorboard-2.20.0 tensorboard-data-server-0.7.2 werkzeug-3.1.8
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy scipy matplotlib opencv-python tqdm pillow scikit-learn lap filterpy motmetrics
# !pip install lap
# !pip install filterpy
# !pip install motmetrics
# Out:
# Requirement already satisfied: numpy in c:\users\vansh\diffmot_env\lib\site-packages (2.4.4)
# Requirement already satisfied: scipy in c:\users\vansh\diffmot_env\lib\site-packages (1.17.1)
# Requirement already satisfied: matplotlib in c:\users\vansh\diffmot_env\lib\site-packages (3.10.8)
# Requirement already satisfied: opencv-python in c:\users\vansh\diffmot_env\lib\site-packages (4.13.0.92)
# Requirement already satisfied: tqdm in c:\users\vansh\diffmot_env\lib\site-packages (4.67.3)
# Requirement already satisfied: pillow in c:\users\vansh\diffmot_env\lib\site-packages (12.1.1)
# Requirement already satisfied: scikit-learn in c:\users\vansh\diffmot_env\lib\site-packages (1.8.0)
# Requirement already satisfied: lap in c:\users\vansh\diffmot_env\lib\site-packages (0.5.13)
# Requirement already satisfied: filterpy in c:\users\vansh\diffmot_env\lib\site-packages (1.4.5)
# Requirement already satisfied: motmetrics in c:\users\vansh\diffmot_env\lib\site-packages (1.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\vansh\diffmot_env\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\vansh\diffmot_env\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\vansh\diffmot_env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas>=0.23.1 in c:\users\vansh\diffmot_env\lib\site-packages (from motmetrics) (3.0.2)
# Requirement already satisfied: xmltodict>=0.12.0 in c:\users\vansh\diffmot_env\lib\site-packages (from motmetrics) (1.0.4)
# Requirement already satisfied: tzdata in c:\users\vansh\diffmot_env\lib\site-packages (from pandas>=0.23.1->motmetrics) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\vansh\diffmot_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: lap in c:\users\vansh\diffmot_env\lib\site-packages (0.5.13)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\vansh\diffmot_env\lib\site-packages (from lap) (2.4.4)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: filterpy in c:\users\vansh\diffmot_env\lib\site-packages (1.4.5)
# Requirement already satisfied: numpy in c:\users\vansh\diffmot_env\lib\site-packages (from filterpy) (2.4.4)
# Requirement already satisfied: scipy in c:\users\vansh\diffmot_env\lib\site-packages (from filterpy) (1.17.1)
# Requirement already satisfied: matplotlib in c:\users\vansh\diffmot_env\lib\site-packages (from filterpy) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib->filterpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib->filterpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib->filterpy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib->filterpy) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib->filterpy) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib->filterpy) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib->filterpy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vansh\diffmot_env\lib\site-packages (from matplotlib->filterpy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vansh\diffmot_env\lib\site-packages (from python-dateutil>=2.7->matplotlib->filterpy) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: motmetrics in c:\users\vansh\diffmot_env\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy>=1.12.1 in c:\users\vansh\diffmot_env\lib\site-packages (from motmetrics) (2.4.4)
# Requirement already satisfied: pandas>=0.23.1 in c:\users\vansh\diffmot_env\lib\site-packages (from motmetrics) (3.0.2)
# Requirement already satisfied: scipy>=0.19.0 in c:\users\vansh\diffmot_env\lib\site-packages (from motmetrics) (1.17.1)
# Requirement already satisfied: xmltodict>=0.12.0 in c:\users\vansh\diffmot_env\lib\site-packages (from motmetrics) (1.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vansh\diffmot_env\lib\site-packages (from pandas>=0.23.1->motmetrics) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\vansh\diffmot_env\lib\site-packages (from pandas>=0.23.1->motmetrics) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\vansh\diffmot_env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23.1->motmetrics) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install yacs
# Out:
# Collecting yacs
#   Using cached yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: PyYAML in c:\users\vansh\diffmot_env\lib\site-packages (from yacs) (6.0.3)
# Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install termcolor
# Out:
# Collecting termcolor
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: termcolor
# Successfully installed termcolor-3.3.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install einops pyyaml argparse easydict numpy tensorboardX tqdm opencv-python scipy lap  fvcore
# Out:
# Requirement already satisfied: einops in c:\users\vansh\diffmot_env\lib\site-packages (0.8.2)
# Requirement already satisfied: pyyaml in c:\users\vansh\diffmot_env\lib\site-packages (6.0.3)
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: easydict in c:\users\vansh\diffmot_env\lib\site-packages (1.13)
# Requirement already satisfied: numpy in c:\users\vansh\diffmot_env\lib\site-packages (2.4.4)
# Requirement already satisfied: tensorboardX in c:\users\vansh\diffmot_env\lib\site-packages (2.6.5)
# Requirement already satisfied: tqdm in c:\users\vansh\diffmot_env\lib\site-packages (4.67.3)
# Requirement already satisfied: opencv-python in c:\users\vansh\diffmot_env\lib\site-packages (4.13.0.92)
# Requirement already satisfied: scipy in c:\users\vansh\diffmot_env\lib\site-packages (1.17.1)
# Requirement already satisfied: lap in c:\users\vansh\diffmot_env\lib\site-packages (0.5.13)
# Collecting fvcore
#   Using cached fvcore-0.1.5.post20221221.tar.gz (50 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: packaging in c:\users\vansh\diffmot_env\lib\site-packages (from tensorboardX) (26.0)
# Requirement already satisfied: protobuf>=3.20 in c:\users\vansh\diffmot_env\lib\site-packages (from tensorboardX) (7.34.1)
# Requirement already satisfied: colorama in c:\users\vansh\diffmot_env\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: yacs>=0.1.6 in c:\users\vansh\diffmot_env\lib\site-packages (from fvcore) (0.1.8)
# Requirement already satisfied: termcolor>=1.1 in c:\users\vansh\diffmot_env\lib\site-packages (from fvcore) (3.3.0)
# Requirement already satisfied: Pillow in c:\users\vansh\diffmot_env\lib\site-packages (from fvcore) (12.1.1)
# Collecting tabulate (from fvcore)
#   Using cached tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Collecting iopath>=0.1.7 (from fvcore)
#   Using cached iopath-0.1.10.tar.gz (42 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: typing_extensions in c:\users\vansh\diffmot_env\lib\site-packages (from iopath>=0.1.7->fvcore) (4.15.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore)
#   Using cached portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting pywin32>=226 (from portalocker->iopath>=0.1.7->fvcore)
#   Downloading pywin32-311-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Using cached tabulate-0.10.0-py3-none-any.whl (39 kB)
# Using cached portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading pywin32-311-cp311-cp311-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB 660.6 kB/s eta 0:00:15
#     --------------------------------------- 0.2/9.5 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/9.5 MB 3.6 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/9.5 MB 4.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/9.5 MB 5.5 MB/s eta 0:00:02
#    ------- -------------------------------- 1.7/9.5 MB 5.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.2/9.5 MB 6.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.8/9.5 MB 7.0 MB/s eta 0:00:01
#    -------------- ------------------------- 3.3/9.5 MB 7.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.0/9.5 MB 7.8 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 8.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 8.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 8.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 8.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 8.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 8.2 MB/s eta 0:00:01
#    -------------------- ------------------- 4.8/9.5 MB 5.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.3/9.5 MB 5.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.5 MB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.5 MB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.5 MB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.5 MB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.5 MB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------- -------------- 6.0/9.5 MB 5.0 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.9/9.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.9/9.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.9/9.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.9/9.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.9/9.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.9/9.5 MB 5.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.2/9.5 MB 4.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.5/9.5 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 8.0/9.5 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.5 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.5 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 4.1 MB/s eta 0:00:00
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (pyproject.toml): started
#   Building wheel for fvcore (pyproject.toml): finished with status 'done'
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61445 sha256=1b4631904d6d9cfc400d8325e758b677881653c8335c03bb6a7217f441c4ac2d
#   Stored in directory: c:\users\vansh\appdata\local\pip\cache\wheels\65\71\95\3b8fde5c65c6e4a806e0867c1651dcc71a1cb2f3430e8f355f
#   Building wheel for iopath (pyproject.toml): started
#   Building wheel for iopath (pyproject.toml): finished with status 'done'
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31606 sha256=960d1a67f3a231e1c27a5b49fc08ad96949e4b1f10678ef36a3990ea50e2d1cf
#   Stored in directory: c:\users\vansh\appdata\local\pip\cache\wheels\ba\5e\16\6117f8fe7e9c0c161a795e10d94645ebcf301ccbd01f66d8ec
# Successfully built fvcore iopath
# Installing collected packages: pywin32, argparse, tabulate, portalocker, iopath, fvcore
# Successfully installed argparse-1.4.0 fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-3.2.0 pywin32-311 tabulate-0.10.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python main.py \
--dataset mot \
--data_dir datasets \
--dataset_name MOT17 \
--mode test \
--device cuda \
--batch_size 1 \
--exp_name mot_ddm_1000_deeper \
--detector FRCNN
# Out:
# > Train Dataset built!
# 2026-04-17 22:54:44 [DEBUG]: matplotlib data path: C:\Users\vansh\diffmot_env\Lib\site-packages\matplotlib\mpl-data
# 2026-04-17 22:54:44 [DEBUG]: CONFIGDIR=C:\Users\vansh\.matplotlib
# 2026-04-17 22:54:44 [DEBUG]: interactive is False
# 2026-04-17 22:54:44 [DEBUG]: platform is win32
# 2026-04-17 22:54:44 [DEBUG]: CACHEDIR=C:\Users\vansh\.matplotlib
# 2026-04-17 22:54:44 [DEBUG]: Using fontManager instance from C:\Users\vansh\.matplotlib\fontlist-v390.json
# C:\Users\vansh\diffmot_env\Lib\site-packages\torchreid\reid\metrics\rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# usage: main.py [-h] [--config CONFIG] [--dataset DATASET]
# main.py: error: unrecognized arguments: --data_dir datasets --dataset_name MOT17 --mode test --device cuda --batch_size 1 --exp_name mot_ddm_1000_deeper --detector FRCNN

# %%
import os
print(os.getcwd())
os.chdir("DiffMOT-main")
print(os.getcwd())
# Out:
# C:\Users\vansh\VANSHIKASOHAL
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main

# %%
# !pip install fastreid
# Out:
# Collecting fastreid
#   Using cached fastreid-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting faiss-cpu<2.0.0,>=1.7.3 (from fastreid)
#   Using cached faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting opencv-python-headless<5.0.0.0,>=4.7.0.68 (from fastreid)
#   Using cached opencv_python_headless-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastreid) (1.8.0)
# Collecting tabulate<0.10.0,>=0.9.0 (from fastreid)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tensorboard<3.0.0,>=2.12.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastreid) (2.20.0)
# Collecting termcolor<3.0.0,>=2.2.0 (from fastreid)
#   Using cached termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# INFO: pip is looking at multiple versions of fastreid to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement torch==1.13.1 (from fastreid) (from versions: 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0)
# ERROR: No matching distribution found for torch==1.13.1

# %%
import sys
import os

# project root
project_path = r"C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main"

# add all required paths
sys.path.insert(0, project_path)
sys.path.insert(0, os.path.join(project_path, "external"))
sys.path.insert(0, os.path.join(project_path, "external", "fast_reid"))
sys.path.insert(0, os.path.join(project_path, "external", "fast_reid", "fastreid"))

print("PATH SET ")
# Out:
# PATH SET

# %%
import os
print(os.getcwd())
os.chdir("DiffMOT-main")
print(os.getcwd())
# Out:
# C:\Users\vansh\VANSHIKASOHAL
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())
# Out:
# Torch version: 2.5.1+cu121
# CUDA available: True
# Device count: 1

# %%
import torch
print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
import fastreid
print("FastReID OK")
# Out:
# FastReID OK

# %%
# !pip install fastreid -U
# Out:
# Collecting fastreid
#   Using cached fastreid-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting faiss-cpu<2.0.0,>=1.7.3 (from fastreid)
#   Using cached faiss_cpu-1.14.2-cp313-cp313-win_amd64.whl.metadata (7.8 kB)
# Collecting opencv-python-headless<5.0.0.0,>=4.7.0.68 (from fastreid)
#   Using cached opencv_python_headless-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.1 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastreid) (1.8.0)
# Collecting tabulate<0.10.0,>=0.9.0 (from fastreid)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tensorboard<3.0.0,>=2.12.0 in C:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastreid) (2.20.0)
# Collecting termcolor<3.0.0,>=2.2.0 (from fastreid)
#   Using cached termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# INFO: pip is looking at multiple versions of fastreid to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement torch==1.13.1 (from fastreid) (from versions: 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0, 2.12.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for torch==1.13.1

# %%
import fastreid
print("FASTREID INSTALLED SUCCESSFULLY")
# Out:
# FASTREID INSTALLED SUCCESSFULLY

# %%
from external.adaptors.fastreid_adaptor import FastReID
print("Adaptor working")
# Out:
# Adaptor working

# %%
from external.adaptors.fastreid_adaptor import FastReID
print("IMPORT SUCCESS ")
# Out:
# IMPORT SUCCESS

# %%
from fastreid.config import get_cfg
from external.adaptors.fastreid_adaptor import FastReID

print("ALL IMPORTS WORKING ")
# Out:
# ALL IMPORTS WORKING

# %%
from external.adaptors.fastreid_adaptor import FastReID

model = FastReID()
print("MODEL LOADED")
# Out:
# MODEL LOADED

# %%
import torch
print("TORCH INSTALLED SUCCESFFULLY !!")
# Out:
# TORCH INSTALLED SUCCESFFULLY !!

# %%
import os
print(os.getcwd())
os.chdir("MOT17")
# Out:
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main\datasets

# %%
print(os.listdir())
# Out:
# ['desktop.ini', 'test', 'train']

# %%
import glob
print(glob.glob("**/det.txt", recursive=True))
# Out:
# ['test\\MOT17-01-DPM\\det\\det.txt', 'test\\MOT17-01-FRCNN\\det\\det.txt', 'test\\MOT17-01-SDP\\det\\det.txt', 'test\\MOT17-03-DPM\\det\\det.txt', 'test\\MOT17-03-FRCNN\\det\\det.txt', 'test\\MOT17-03-SDP\\det\\det.txt', 'test\\MOT17-06-DPM\\det\\det.txt', 'test\\MOT17-06-FRCNN\\det\\det.txt', 'test\\MOT17-06-SDP\\det\\det.txt', 'test\\MOT17-07-DPM\\det\\det.txt', 'test\\MOT17-07-FRCNN\\det\\det.txt', 'test\\MOT17-07-SDP\\det\\det.txt', 'test\\MOT17-08-DPM\\det\\det.txt', 'test\\MOT17-08-FRCNN\\det\\det.txt', 'test\\MOT17-08-SDP\\det\\det.txt', 'test\\MOT17-12-DPM\\det\\det.txt', 'test\\MOT17-12-FRCNN\\det\\det.txt', 'test\\MOT17-12-SDP\\det\\det.txt', 'test\\MOT17-14-DPM\\det\\det.txt', 'test\\MOT17-14-FRCNN\\det\\det.txt', 'test\\MOT17-14-SDP\\det\\det.txt', 'train\\MOT17-02-FRCNN\\det\\det.txt', 'train\\MOT17-05-FRCNN\\det\\det.txt', 'train\\MOT17-09-FRCNN\\det\\det.txt', 'train\\MOT17-10-FRCNN\\det\\det.txt', 'train\\MOT17-11-FRCNN\\det\\det.txt', 'train\\MOT17-13-FRCNN\\det\\det.txt']

# %%
import os
print(os.listdir("train"))
print(os.listdir("test"))
# Out:
# ['desktop.ini', 'MOT17-02-FRCNN', 'MOT17-04-FRCNN', 'MOT17-05-FRCNN', 'MOT17-09-FRCNN', 'MOT17-10-FRCNN', 'MOT17-11-FRCNN', 'MOT17-13-FRCNN']
# ['desktop.ini', 'MOT17-01-DPM', 'MOT17-01-FRCNN', 'MOT17-01-SDP', 'MOT17-03-DPM', 'MOT17-03-FRCNN', 'MOT17-03-SDP', 'MOT17-06-DPM', 'MOT17-06-FRCNN', 'MOT17-06-SDP', 'MOT17-07-DPM', 'MOT17-07-FRCNN', 'MOT17-07-SDP', 'MOT17-08-DPM', 'MOT17-08-FRCNN', 'MOT17-08-SDP', 'MOT17-12-DPM', 'MOT17-12-FRCNN', 'MOT17-12-SDP', 'MOT17-14-DPM', 'MOT17-14-FRCNN', 'MOT17-14-SDP']

# %%
import os
print(os.getcwd())
os.chdir("./")
print(os.listdir("datasets/MOT17/train"))
# Out:
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main
# ['.ipynb_checkpoints', 'desktop.ini', 'MOT17-02', 'MOT17-02-FRCNN', 'MOT17-04', 'MOT17-04-FRCNN', 'MOT17-05', 'MOT17-05-FRCNN', 'MOT17-09', 'MOT17-09-FRCNN', 'MOT17-10', 'MOT17-10-FRCNN', 'MOT17-11', 'MOT17-11-FRCNN', 'MOT17-13', 'MOT17-13-FRCNN']

# %%
import glob

print(glob.glob("datasets/MOT17/train/*"))
# Out:
# ['datasets/MOT17/train\\desktop.ini', 'datasets/MOT17/train\\MOT17-02', 'datasets/MOT17/train\\MOT17-02-FRCNN', 'datasets/MOT17/train\\MOT17-04', 'datasets/MOT17/train\\MOT17-04-FRCNN', 'datasets/MOT17/train\\MOT17-05', 'datasets/MOT17/train\\MOT17-05-FRCNN', 'datasets/MOT17/train\\MOT17-09', 'datasets/MOT17/train\\MOT17-09-FRCNN', 'datasets/MOT17/train\\MOT17-10', 'datasets/MOT17/train\\MOT17-10-FRCNN', 'datasets/MOT17/train\\MOT17-11', 'datasets/MOT17/train\\MOT17-11-FRCNN', 'datasets/MOT17/train\\MOT17-13', 'datasets/MOT17/train\\MOT17-13-FRCNN']

# %%
import os

paths = {
    "Motion Model": "pretrained/motion/MOT_epoch800.pt",
    "ReID Model": "pretrained/reid/mot17_sbs_S50.pth",
    "Detections": "datasets/MOT17/train/MOT17-09-FRCNN/det/det.txt"
}

for name, path in paths.items():
    print(f"\n{name}:")
    print("Path:", path)
    print("Exists:", os.path.exists(path))
    
    if os.path.exists(path):
        size = os.path.getsize(path) / (1024*1024)
        print(f"Size: {size:.2f} MB")
# Out:
# Motion Model:
# Path: pretrained/motion/MOT_epoch800.pt
# Exists: True
# Size: 168.32 MB
#
# ReID Model:
# Path: pretrained/reid/mot17_sbs_S50.pth
# Exists: True
# Size: 302.89 MB
#
# Detections:
# Path: datasets/MOT17/train/MOT17-09-FRCNN/det/det.txt
# Exists: True
# Size: 0.25 MB

# %%
import os
print(os.getcwd())
print(os.listdir())
# %cd ..
print(os.getcwd())
print(os.listdir("experiments"))
# Out:
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main\datasets
# ['.ipynb_checkpoints', 'MOT17']
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main
# ['external', 'mot_ddm_1000_deeper']
# C:\Users\vansh\gpu_env\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
print(os.listdir("experiments"))
# Out:
# ['external', 'mot_ddm_1000_deeper']

# %%
import os
print(os.listdir("experiments/mot_ddm_1000_deeper"))
# Out:
# ['.ipynb_checkpoints', 'events.out.tfevents.1775570875.RajeshMehta', 'events.out.tfevents.1775572403.RajeshMehta', 'events.out.tfevents.1775572469.RajeshMehta', 'events.out.tfevents.1776447059.VSDELL', 'events.out.tfevents.1776447347.VSDELL', 'events.out.tfevents.1776448631.VSDELL', 'events.out.tfevents.1776448976.VSDELL', 'events.out.tfevents.1776449185.VSDELL', 'events.out.tfevents.1776449533.VSDELL', 'events.out.tfevents.1776449650.VSDELL', 'events.out.tfevents.1776449874.VSDELL', 'events.out.tfevents.1776449913.VSDELL', 'events.out.tfevents.1776454290.VSDELL', 'events.out.tfevents.1776454339.VSDELL', 'events.out.tfevents.1776454720.VSDELL', 'events.out.tfevents.1779853287.VSDELL', 'events.out.tfevents.1779855784.VSDELL', 'events.out.tfevents.1779857724.VSDELL', 'events.out.tfevents.1779857930.VSDELL', 'events.out.tfevents.1779858175.VSDELL', 'events.out.tfevents.1779858336.VSDELL', 'events.out.tfevents.1779858677.VSDELL', 'events.out.tfevents.1779858827.VSDELL', 'events.out.tfevents.1779860770.VSDELL', 'events.out.tfevents.1779861341.VSDELL', 'events.out.tfevents.1779862092.VSDELL', 'events.out.tfevents.1779862230.VSDELL', 'events.out.tfevents.1779862299.VSDELL', 'events.out.tfevents.1779862455.VSDELL', 'events.out.tfevents.1779862835.VSDELL', 'events.out.tfevents.1779863211.VSDELL', 'events.out.tfevents.1779863599.VSDELL', 'events.out.tfevents.1779863620.VSDELL', 'events.out.tfevents.1779863826.VSDELL', 'events.out.tfevents.1779865220.VSDELL', 'events.out.tfevents.1779866912.VSDELL', 'events.out.tfevents.1779867696.VSDELL', 'MOT17_2026-04-17-23-47.log', 'MOT17_2026-04-17-23-48.log', 'MOT17_2026-05-27-09-11.log', 'MOT17_2026-05-27-09-53.log', 'MOT17_2026-05-27-10-25.log', 'MOT17_2026-05-27-10-28.log', 'MOT17_2026-05-27-10-32.log', 'MOT17_2026-05-27-10-35.log', 'MOT17_2026-05-27-10-41.log', 'MOT17_2026-05-27-10-43.log', 'MOT17_2026-05-27-11-16.log', 'MOT17_2026-05-27-11-25.log', 'MOT17_2026-05-27-11-38.log', 'MOT17_2026-05-27-11-40.log', 'MOT17_2026-05-27-11-41.log', 'MOT17_2026-05-27-11-44.log', 'MOT17_2026-05-27-11-50.log', 'MOT17_2026-05-27-11-56.log', 'MOT17_2026-05-27-12-03.log', 'MOT17_2026-05-27-12-07.log', 'MOT17_2026-05-27-12-30.log', 'MOT17_2026-05-27-12-58.log', 'MOT17_2026-05-27-13-11.log', '_2026-04-07-19-37.log', '_2026-04-07-20-03.log', '_2026-04-07-20-04.log', '_2026-04-17-23-00.log', '_2026-04-17-23-05.log', '_2026-04-17-23-27.log', '_2026-04-17-23-32.log', '_2026-04-17-23-36.log', '_2026-04-17-23-42.log', '_2026-04-17-23-44.log', '_2026-04-18-01-01.log', '_2026-04-18-01-02.log', '_2026-04-18-01-08.log', '_epoch800.pt']

# %%
# !python main.py --config configs/mot.yaml --dataset MOT17
#ran in cmd mode

# %%
import glob
import os

ckpts = glob.glob("experiments/mot_ddm_80/**/*.pth", recursive=True)

print("CHECKPOINTS FOUND:\n")
for c in ckpts:
    print(os.path.basename(c))

# %%
from diffmot import DiffMOT
import yaml

# Load config
with open("configs/mot.yaml", 'r') as f:
    config = yaml.safe_load(f)

# IMPORTANT: set eval_mode True
config["eval_mode"] = True

# Load trained model
agent = DiffMOT(config)

# Run tracking
agent.eval()

# %%
# !pip install trackeval -q
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
python -m trackeval.scripts.run_mot_challenge ^
--SPLIT_TO_EVAL train ^
--METRICS HOTA Identity ^
--GT_FOLDER datasets/mot/train ^
--TRACKERS_FOLDER outputs/mot17 ^
--TRACKER_SUB_FOLDER "" ^
--USE_PARALLEL False ^
--NUM_PARALLEL_CORES 1 ^
--PRINT_RESULTS True ^
--OUTPUT_SUMMARY True

# %%
import pandas as pd

for sf in summary_files:
    print(f"\n {sf}")
    df = pd.read_csv(sf, sep=' ')
    print(df)

# %%
import os

path = r"C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main\datasets\MOT17\train\MOT17-04-FRCNN\seqinfo.ini"

print("Exists:", os.path.exists(path))
# Out:
# Exists: True

# %%
import os

print(os.listdir("experiments/mot_ddm_1000_deeper"))
# Out:
# ['.ipynb_checkpoints', 'events.out.tfevents.1775570875.RajeshMehta', 'events.out.tfevents.1775572403.RajeshMehta', 'events.out.tfevents.1775572469.RajeshMehta', 'events.out.tfevents.1776447059.VSDELL', 'events.out.tfevents.1776447347.VSDELL', 'events.out.tfevents.1776448631.VSDELL', 'events.out.tfevents.1776448976.VSDELL', 'events.out.tfevents.1776449185.VSDELL', 'events.out.tfevents.1776449533.VSDELL', 'events.out.tfevents.1776449650.VSDELL', 'events.out.tfevents.1776449874.VSDELL', 'events.out.tfevents.1776449913.VSDELL', 'events.out.tfevents.1776454290.VSDELL', 'events.out.tfevents.1776454339.VSDELL', 'events.out.tfevents.1776454720.VSDELL', 'events.out.tfevents.1779853287.VSDELL', 'events.out.tfevents.1779855784.VSDELL', 'events.out.tfevents.1779857724.VSDELL', 'events.out.tfevents.1779857930.VSDELL', 'events.out.tfevents.1779858175.VSDELL', 'events.out.tfevents.1779858336.VSDELL', 'events.out.tfevents.1779858677.VSDELL', 'events.out.tfevents.1779858827.VSDELL', 'events.out.tfevents.1779860770.VSDELL', 'events.out.tfevents.1779861341.VSDELL', 'events.out.tfevents.1779862092.VSDELL', 'events.out.tfevents.1779862230.VSDELL', 'events.out.tfevents.1779862299.VSDELL', 'events.out.tfevents.1779862455.VSDELL', 'events.out.tfevents.1779862835.VSDELL', 'events.out.tfevents.1779863211.VSDELL', 'events.out.tfevents.1779863599.VSDELL', 'events.out.tfevents.1779863620.VSDELL', 'events.out.tfevents.1779863826.VSDELL', 'events.out.tfevents.1779865220.VSDELL', 'events.out.tfevents.1779866912.VSDELL', 'events.out.tfevents.1779867696.VSDELL', 'MOT17_2026-04-17-23-47.log', 'MOT17_2026-04-17-23-48.log', 'MOT17_2026-05-27-09-11.log', 'MOT17_2026-05-27-09-53.log', 'MOT17_2026-05-27-10-25.log', 'MOT17_2026-05-27-10-28.log', 'MOT17_2026-05-27-10-32.log', 'MOT17_2026-05-27-10-35.log', 'MOT17_2026-05-27-10-41.log', 'MOT17_2026-05-27-10-43.log', 'MOT17_2026-05-27-11-16.log', 'MOT17_2026-05-27-11-25.log', 'MOT17_2026-05-27-11-38.log', 'MOT17_2026-05-27-11-40.log', 'MOT17_2026-05-27-11-41.log', 'MOT17_2026-05-27-11-44.log', 'MOT17_2026-05-27-11-50.log', 'MOT17_2026-05-27-11-56.log', 'MOT17_2026-05-27-12-03.log', 'MOT17_2026-05-27-12-07.log', 'MOT17_2026-05-27-12-30.log', 'MOT17_2026-05-27-12-58.log', 'MOT17_2026-05-27-13-11.log', '_2026-04-07-19-37.log', '_2026-04-07-20-03.log', '_2026-04-07-20-04.log', '_2026-04-17-23-00.log', '_2026-04-17-23-05.log', '_2026-04-17-23-27.log', '_2026-04-17-23-32.log', '_2026-04-17-23-36.log', '_2026-04-17-23-42.log', '_2026-04-17-23-44.log', '_2026-04-18-01-01.log', '_2026-04-18-01-02.log', '_2026-04-18-01-08.log', '_epoch800.pt']

# %%
import glob

ckpts = glob.glob("experiments/mot_ddm_1000_deeper/**/*.pth", recursive=True)

print("Checkpoints:")
for c in ckpts:
    print(c)
# Out:
# Checkpoints:

# %%
import os

print(os.getcwd())
print(os.listdir())
print(os.listdir())
# Out:
# C:\Users\vansh\VANSHIKASOHAL\DiffMOT-main\datasets\MOT17\train
# ['desktop.ini', 'MOT17-02-FRCNN', 'MOT17-04-FRCNN', 'MOT17-05-FRCNN', 'MOT17-09-FRCNN', 'MOT17-10-FRCNN', 'MOT17-11-FRCNN', 'MOT17-13-FRCNN', 'seqmaps']
# ['desktop.ini', 'MOT17-02-FRCNN', 'MOT17-04-FRCNN', 'MOT17-05-FRCNN', 'MOT17-09-FRCNN', 'MOT17-10-FRCNN', 'MOT17-11-FRCNN', 'MOT17-13-FRCNN', 'seqmaps']
